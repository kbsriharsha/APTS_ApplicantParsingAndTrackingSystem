# %%
# importing libraries
import re
import pyap

# %%
txt = "this is spain"

EMAIL_REGEX = r"[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,4}"
PHONE_REGEX = r"\(?(\d{3})?\)?[\s\.-]{0,2}?(\d{3})[\s\.-]{0,2}(\d{4})"

re.search("spain", txt)
# Out:
# <_sre.SRE_Match object; span=(8, 13), match='spain'>

# %%
mob_num_regex = r'''\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}
                    |\(\d{3}\)[-\.\s]*\d{3}[-\.\s]??\d{4}
                    |\d{3}[-\.\s]??\d{4}
                    |\(\d{3}[)-\.\s].\d{3}.\d{4}'''

# %%
phone = re.findall(re.compile(mob_num_regex), '+1 (205) 200-8202')
phone
# Out:
# ['(205) 200-8202']

# %%
re.findall(re.compile(r'\(\d{3}[)-\.\s].\d{3}.\d{4}'), '+1 (205) 200-8202')
# Out:
# ['(205) 200-8202']

# %%
test_address = """
    94 Central Avenue Jersey City NJ 07306
    """

# %%
addresses = pyap.parse(test_address, country='US')

# %%
addresses
# Out:
# [94 Central Avenue Jersey City NJ 07306]

# %%
import spacy

# %%
sp_lg = spacy.load('en_core_web_lg')
{(ent.text.strip(), ent.label_) for ent in sp_lg(document).ents}
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-106-b4b88fd4ddb4> in <module>
# ----> 1 sp_lg = spacy.load('en_core_web_lg')
#       2 {(ent.text.strip(), ent.label_) for ent in sp_lg(document).ents}
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     137     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     138         return load_model_from_path(name, **overrides)
# --> 139     raise IOError(Errors.E050.format(name=name))
#     140
#     141
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
import sys
sys.version
# Out:
# '3.6.8 |Anaconda custom (64-bit)| (default, Dec 29 2018, 19:04:46) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
np = spacy.load('en_core_web_lg')

# %%
docs = np("""Bharat Sri Harsha Karpurapu authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices""")

# %%
print((X.text, X.label_) for X in docs.ents])
# Out:
# (Bharat Sri Harsha Karpurapu, Google, $5.1 billion, Wednesday)

# %%
# Importing libraries
import sys
import os
import re
import pyap
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convertPDFToText(path):
    """
    This function converts pdf to text

    path: path of the file to be converted
    """
    fp = open(path, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    return data

# %%
f = convertPDFToText("resume_trail1.pdf")
f1 = re.sub("\n", "", f)

# %%
f
# Out:
# '                        Managing Partner and Program Manager/Engineer \n\n                                          Erick B. Knezek \n\n \n\n \n\n \n\n \nEducation \n\n\uf0a7  B.S., Ocean Engineering, United \n\nStates Naval Academy, 1996 \n\n\uf0a7  M.S., Ocean Engineering, Texas A \n\n& M, 1997 \n\nYears of Experience - 18 \n\nProfessional Engineer \n\nMaryland,  \n\nQualified Navy Deep Sea Diver \n\nand Dive Supervisor \n\nRELEVANT EXPERIENCE \n\nMr.  Knezek  has  more  than  18  years  of  program/technical \nmanagement,  civil  and  ocean  engineering,  and  construction \nexperience.  He  has  managed  numerous  projects  over  the  past  14 \nyears  while  executing  engineering  projects  worldwide  including \nmanagement of pier design, installation and repair projects.  Erick \nhas  been \nthe  planning,  program  policy \ndevelopment, \nfinancial  management,  manpower  allocation, \nlogistics,  and  technical  management  of  construction  activities  at \nfacilities worldwide.  \n\nresponsible \n\nfor \n\nMr.  Knezek  is  a  former  US  Navy  Civil  Engineer  Corps  Officer. \nThat  along  with  his  background  as  a  Professional  Engineer  and \ngive him the expertise to understand the complex issues that may \narise.    Erick’s  professional  competence  and  expertise  has  been \nrecognized  by  the  highly  competitive  Louisiana  oil  and  gas \nindustry  where  he  featured  as  one  of  five  “Top  Young  Stars  to \nWatch in the Oil and Gas Industry” in October 2013 by the Daily \nAdvertiser. \n\nProgram  Manager,  Truston  Technologies  Ocean  Facilities  Support  Services  Multiple \nAward  Contract  –  N62583-09-D-0065  (2009-present)  -  $250M  -  Erick  is  Program \nManager for this 5 year IDIQ contract with the Navy. The multiple specialty areas including \nwaterfront  DLA/Navy  Petroleum  Handling  Facilities,  Underwater  Fuel  Pipelines,  SBM \nFueling  offload  buoys,  Specialized  Moorings,  Ocean  Energy  and  Marine  Power  Systems, \nUnderwater Cable Facilities and Shore Landings, and Magnetic Silencing Facilities.  Specific \nProjects  included  the  inspection  and  repairs  of  the  Tengan  Petroleum  Handling  Facility  in \nOkinawa. This project included the Pipe Line End Manifold system API design, fabrication, \nand  installation,  submarine  hose  string  procurement  as  well  as  pipeline  inspection  and \ntesting.  Also  included  was  the  Wake  Island  DLA  Fuel  System  Upgrades.  This  showcased \nErick’s  deep  understanding  of  the  complex  logistics  involved  in  remote  POL  projects  as \nTruston  transported  material  and  equipment  from  Guam  by  barge  and  an  aircraft  from \nHawaii coordinating their simultaneous arrival. \nProgram  Manager,  Truston  Technologies  Waterfront  Barriers  Support  Services \nMultiple  Award  Contract  –  N62583-10-D-0341  (2010-present)  –  $150M  -  Program \nManager  for  this  NAVFAC  EXWC  IDIQ  contract  awarded  in  2009.    The  work  involved \nincluded the steel and composite fabrication, installation, maintenance, repair, modifications \nand  upgrades  to  Security  Barrier  Systems  worldwide.    In  particular,  Erick  successfully \nexecuted complex logistical projects at dozens of Naval facilities throughout the world with \nmany projects running simultaneously and requiring significant coordination between EXWC \ncontracts  and  NTR  personnel,  as  well  as  local  FEAD/ROICC  customers.    His  keen \nunderstanding  of  managing  the  dual  customer  relationship  of  EXWC  and  local  base \npersonnel resulted in successful project execution. \nProgram  Manager,  Truston  Technologies  Marine  Services-  N62583-08-D-0056  (2008-\n2010) – $3.5M -  Program Manager for this NAVFAC EXWC IDIQ contract which included \n\n \n \n\nPage No. 1 \n \n\n\x0c                        Managing Partner and Program Manager/Engineer \n\n                                          Erick B. Knezek \n\na  variety  of  sustainment, ...

# %%
doc1 = np("BHARAT Sri Harsha Karpurapu")

# %%
f1
# Out:
# '94, Central Ave, APT 1, Jersey City, NJ, 07306 BHARAT SRI HARSHA KARPURAPU +1 (205) 200-8202 kbsriharsha@gmail.com  https://github.com/kbsriharsha/DataScience (Aug 2015 – April 2017) (June 2018 – Current) https://www.linkedin.com/in/kbsriharsha/   Seasoned data scientist with nearly 4 plus years of domain experience through professional work and research,  and with demonstrated abilities in delivering actionable insights using advanced data-driven methods  Proven credentials in developing and delivering complex business solutions with strong emphasis on machine  learning, deep learning, big data analytics, natural language processing, statistics, and high-performance computing  Has expert level of knowledge in various data science technology platforms and highly skilled in orchestrating data from various sources (on premise, cloud, and different vendors) and developing data driven predictive applications   PROFESSIONAL EXPERIENCE   New York Life Insurance – New York City, NY  Senior Associate, Data Science  - Functioning as one of the data experts and tech liaisons of the team assigned to curate, design, and develop the model ready data sets and introduce the latest cutting edge algorithms and platforms for increased computation speed and accuracy  - Successfully designed and implemented a process for cleaning the unstructured beneficiary records using Natural Language Processing techniques and saved 2 million$ vendor cost  - Creating model ready dataset (MRD) for agent compliance model; which is aimed to classify the non-compliant vs compliant agents as per the NYL rules  Regions Bank – Birmingham, AL  Data Scientist (June 2017 – May 2018) Data Scientist Intern (Jan 2016 – May 2017)  - Part of the new data science team (4 members) created under the CDO (Chief Data Officer) for developing predictive analytics and augmented intelligence applications to help the bank in process improvement and for finding new opportunities  - As a team, assigned to create and architect an enterprise big data environment with Hadoop echo system and IBM Power Minskey (Nvidia P100 GPU’s) to facilitate data science team and quant squad in the bank  - Successfully  developed  applications  like  Intelligent  Web  Scrapper  for  getting  information  on  potential  customers from the web, Regions Business Universe which facilitates various departments of the bank to take quick customer decisions and contributed in delivering quick process for CIP (Customer Identification Program) which decrease the process time from 20 min to 3 min  - Acted as lead role for determining the POCO (Probability of Charge-off) for an overdraft account, and replaced the  old model with the new model with 4% increase in accuracy.   EDUCATION   University of Alabama at Birmingham (Master’s Degree)  Electrical and Computer Engineering Dept. (Data Science Concentration) (G.P.A: 4.0)  Research Fields: Machine Learning, Deep Learning, Big Data Analytics, Natural Language Processing, and High Performance Computing  Thesis Title: Framework for Social Network Sentiment Analysis Using Big Data Analytics  - Developed a generalized framework for performing social network sentiment analysis on any kind of domain such as automobile, banking and telecom  - Studied numerous research papers on natural language processing, big data analytics and machine learning   Publication: Big Data and Visual Analytics, Springer 2017, Chapter 12, Page: 203-218 * Case Study: Automobile * Popular: BMW * Highest Sentiment: Mercedes (0.87) * Lowest Sentiment: Buick(0.49) (Jan 2016 –May 2018) \x0c'

# %%
print([(X.text, X.label_) for X in doc1.ents])
# Out:
# [('BHARAT', 'ORG'), ('Harsha Karpurapu', 'PERSON')]

# %%
from pyresparser import ResumeParser

# %%
ResumeParser('Resume_Harsha_Updated.pdf').get_extracted_data()
# Out:
# {'name': 'Central Ave',
#  'email': 'kbsriharsha@gmail.com',
#  'mobile_number': None,
#  'skills': ['Compliance',
#   'Improvement',
#   'Machine learning',
#   'Design',
#   'Telecom',
#   'Engineering',
#   'Process improvement',
#   'System',
#   'Statistics',
#   'Algorithms',
#   'Visual',
#   'Analysis',
#   'Ibm',
#   'Process',
#   'Hadoop',
#   'Banking',
#   'Vendors',
#   'Electrical',
#   'Analytics',
#   'Research',
#   'Big data',
#   'Cloud',
#   'Predictive analytics'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': ['New York Life Insurance – New York City, NY',
#   'Senior Associate, Data Science',
#   '- Functioning as one of the data experts and tech liaisons of the team assigned to curate, design, and develop the',
#   'model ready data sets and introduce the latest cutting edge algorithms and platforms for increased computation',
#   'speed and accuracy',
#   '- Successfully designed and implemented a process for cleaning the unstructured beneficiary records',
#   'using Natural Language Processing techniques and saved 2 million$ vendor cost',
#   '- Creating model ready dataset (MRD) for agent compliance model; which is aimed to classify the non-compliant',
#   'vs compliant agents as per the NYL rules',
#   'Regions Bank – Birmingham, AL',
#   'Data Scientist (June 2017 – May 2018)',
#   'Data Scientist Intern (Jan 2016 – May 2017)',
#   '- Part of the new data science team (4 members) created under the CDO (Chief Data Officer) for developing',
#   'predictive analytics and augmented intelligence applications to help the bank in process improvement and for finding',
#   'new opportunities',
#   '- As a team, assigned to create and architect an enterprise big data environment with Hadoop echo system and IBM',
#   'Power Minskey (Nvidia P100 GPU’s) to facilitate data science team and quant squad in the bank',
#   '- Successfully  developed  applications  like  Intelligent  Web  Scrapper  for  getting  information  on  potential  customers',
#   'from the web, Regions Business Universe which facilitates various departments of the bank to take quick customer',
#   'decisions and contributed in delivering quick process for CIP (Customer Identification Program) which decrease the',
#   'process time from 20 min to 3 min',
#   '- Acted as lead role for determining the POCO (Probability of Charge-off) for an overdraft account, and replaced the',
#   'old model with the new model with 4% increase in accuracy.'],
#  'company_names': None,
#  'no_of_pages': 1,
#  'total_experience': 2.25}

# %%
import nltk
#grammar = r'{<NN.*><NN.*><NN.*>*}'
#chunkParser = nltk.RegexpParser(grammar)

# %%
nltk.sent_tokenize(f)[2]
[nltk.pos_tag(sent) for sent in nltk.sent_tokenize(f)]
# Out:
# [[('9', 'CD'),
#   ('4', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('A', 'DT'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('A', 'NNP'),
#   ('P', 'NNP'),
#   ('T', 'NNP'),
#   (' ', 'NNP'),
#   ('1', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('J', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('e', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'NN'),
#   ('y', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('J', 'NNP'),
#   (',', ','),
#   (' ', 'VBD'),
#   ('0', 'CD'),
#   ('7', 'CD'),
#   ('3', 'CD'),
#   ('0', 'CD'),
#   ('6', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('B', 'NNP'),
#   ('H', 'NNP'),
#   ('A', 'NNP'),
#   ('R', 'NNP'),
#   ('A', 'NNP'),
#   ('T', 'NNP'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('R', 'NNP'),
#   ('I', 'PRP'),
#   (' ', 'VBP'),
#   ('H', 'PRP'),
#   ('A', 'DT'),
#   ('R', 'NNP'),
#   ('S', 'NNP'),
#   ('H', 'NNP'),
#   ('A', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('K', 'NNP'),
#   ('A', 'NNP'),
#   ('R', 'NNP'),
#   ('P', 'NNP'),
#   ('U', 'NNP'),
#   ('R', 'NNP'),
#   ('A', 'NNP'),
#   ('P', 'NNP'),
#   ('U', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('+', 'VBD'),
#   ('1', 'CD'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('5', 'CD'),
#   (')', ')'),
#   (' ', 'VBD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('0', 'CD'),
#   ('-', ':'),
#   ('8', 'CD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('2', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('@', 'JJ'),
#   ('g', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('l', 'NN'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('t', 'NN'),
#   ('p', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   ('/', 'JJ'),
#   ('/', 'NNP'),
#   ('g', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   ('u', 'JJ'),
#   ('b', 'NN'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('/', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('/', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   ('S', 'NNP'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('J', 'NNP'),
#   ('u', 'RB'),
#   ('n', 'RB'),
#   ('e', 'JJ'),
#   (' ', 'VBP'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('t', 'NN'),
#   ('p', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   ('/', 'JJ'),
#   ('/', 'NNP'),
#   ('w', 'NN'),
#   ('w', 'NN'),
#   ('w', 'NN'),
#   ('.', '.'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('k', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('/', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('/', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('/', 'JJ'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('s', 'NN'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'RB'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   (' ', 'VBD'),
#   ('4', 'CD'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('y', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('n', 'NN'),
#   (' ', 'NNP'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('h', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('g', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('f', 'NN'),
#   ('e', 'NN'),
#   ('s', 'VBD'),
#   ('s', 'JJ'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'IN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('m', 'NN'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   ('i', 'JJ'),
#   ('t', 'VBP'),
#   ('i', 'JJ'),
#   ('e', 'VBP'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'IN'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('d', 'NN'),
#   ('v', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   ('-', ':'),
#   ('d', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('t', 'NN'),
#   ('h', 'NN'),
#   ('o', 'JJ'),
#   ('d', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('c', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'IN'),
#   ('p', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('u', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'NN'),
#   ('l', 'NN'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('e', 'VBZ'),
#   ('m', 'FW'),
#   ('p', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('m', 'NN'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('i', 'JJ'),
#   ('n', 'VBP'),
#   ('e', 'JJ'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('e', 'FW'),
#   ('e', 'FW'),
#   ('p', 'FW'),
#   (' ', 'FW'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('n', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('s', 'VBZ'),
#   ('t', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'SYM'),
#   ('-', ':'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('p', 'NN'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('H', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('k', 'NN'),
#   ('n', 'NNP'),
#   ('o', 'VBZ'),
#   ('w', 'JJ'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('v', 'FW'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('s', 'NN'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('n', 'JJ'),
#   ('o', 'NN'),
#   ('l', 'NN'),
#   ('o', 'NN'),
#   ('g', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'NN'),
#   ('s', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('k', 'NN'),
#   ('i', 'JJ'),
#   ('l', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('f', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('v', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('o', 'JJ'),
#   ('n', 'RB'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('e', 'IN'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('l', 'JJ'),
#   ('o', 'JJ'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('f', 'VBP'),
#   ('f', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'IN'),
#   ('p', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('R', 'NNP'),
#   ('O', 'NNP'),
#   ('F', 'NNP'),
#   ('E', 'NNP'),
#   ('S', 'NNP'),
#   ('S', 'NNP'),
#   ('I', 'PRP'),
#   ('O', 'NNP'),
#   ('N', 'NNP'),
#   ('A', 'NNP'),
#   ('L', 'NNP'),
#   (' ', 'NNP'),
#   ('E', 'NNP'),
#   ('X', 'NNP'),
#   ('P', 'NNP'),
#   ('E', 'NNP'),
#   ('R', 'NNP'),
#   ('I', 'PRP'),
#   ('E', 'VBP'),
#   ('N', 'NNP'),
#   ('C', 'NNP'),
#   ('E', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   (' ', 'NNP'),
#   ('Y', 'NNP'),
#   ('o', 'MD'),
#   ('r', 'VB'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('i', 'NN'),
#   ('f', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('I', 'PRP'),
#   ('n', 'VBP'),
#   ('s', 'JJ'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('–', 'NNP'),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   (' ', 'NNP'),
#   ('Y', 'NNP'),
#   ('o', 'MD'),
#   ('r', 'VB'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'NN'),
#   ('y', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('Y', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ...],
#  [('E', 'NNP'),
#   ('D', 'NNP'),
#   ('U', 'NNP'),
#   ('C', 'NNP'),
#   ('A', 'NNP'),
#   ('T', 'NNP'),
#   ('I', 'PRP'),
#   ('O', 'NNP'),
#   ('N', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('U', 'NNP'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'IN'),
#   ('A', 'NNP'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('r', 'VBP'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   ('h', 'NN'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   (' ', 'NN'),
#   ('(', '('),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('g', 'NN'),
#   ('r', 'NN'),
#   ('e', 'FW'),
#   ('e', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('\n', 'JJ'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('E', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('c', 'NN'),
#   ('t', 'IN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('m', 'VB'),
#   ('p', 'JJ'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('E', 'NNP'),
#   ('n', 'IN'),
#   ('g', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('p', 'NN'),
#   ('t', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('D', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('S', 'NNP'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('n', 'VB'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('n', 'NNS'),
#   ('t', 'VBP'),
#   ('r', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'NN'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('(', '('),
#   ('G', 'NNP'),
#   ('.', '.'),
#   ('P', 'NNP'),
#   ('.', '.'),
#   ('A', 'DT'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('4', 'CD'),
#   ('.', '.'),
#   ('0', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('R', 'NNP'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('F', 'NNP'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('l', 'NN'),
#   ('d', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('i', 'JJ'),
#   ('n', 'VBP'),
#   ('e', 'JJ'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('e', 'NN'),
#   ('p', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('H', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('m', 'VB'),
#   ('p', 'JJ'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('T', 'NNP'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'IN'),
#   ('T', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('F', 'NNP'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('o', 'IN'),
#   ('c', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('t', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'VBD'),
#   ('A', 'NNP'),
#   ('n', 'FW'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('U', 'NNP'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('-', ':'),
#   (' ', 'NN'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'NN'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('e', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('z', 'VBP'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'VBZ'),
#   ('r', 'VB'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'IN'),
#   ('c', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'CC'),
#   ('e', 'JJ'),
#   ('t', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('k', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('n', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('s', 'VBD'),
#   ('u', 'JJ'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('o', 'NN'),
#   ('m', 'NN'),
#   ('o', 'IN'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('k', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('c', 'VBP'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('-', ':'),
#   (' ', 'NN'),
#   ('S', 'NNP'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'CC'),
#   ('u', 'JJ'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'VBZ'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('n', 'FW'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('m', 'VBZ'),
#   ('a', 'DT'),
#   ('c', 'JJ'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('u', 'NN'),
#   ('b', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('V', 'NNP'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('p', 'IN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'VBD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('7', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'VBD'),
#   ('1', 'CD'),
#   ('2', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('a', 'DT'),
#   ('g', 'JJ'),
#   ('e', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('3', 'CD'),
#   ('-', ':'),
#   ('2', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   ('y', 'NN'),
#   (':', ':'),
#   (' ', 'VB'),
#   ('A', 'DT'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('o', 'NN'),
#   ('m', 'NN'),
#   ('o', 'IN'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('o', 'MD'),
#   ('p', 'VB'),
#   ('u', 'JJ'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('M', 'NNP'),
#   ('W', 'NNP'),
#   (' ', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('H', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('M', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('0', 'CD'),
#   ('.', '.'),
#   ('8', 'CD'),
#   ('7', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('o', 'MD'),
#   ('w', 'VB'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('u', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('k', 'NN'),
#   ('(', '('),
#   ('0', 'CD'),
#   ('.', '.'),
#   ('4', 'CD'),
#   ('9', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('J', 'NNP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   (' ', 'NN'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('6', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('y', 'NN'),
#   (' ', 'VBZ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('A', 'NNP'),
#   ('u', 'RB'),
#   ('g', 'VBZ'),
#   (' ', 'JJ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('5', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   (' ', 'VBZ'),
#   ('A', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   (' ', '$'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('7', 'CD'),
#   (')', ')')]]

# %%
def preprocess(document):
        '''
        Information Extraction: Preprocess a document with the necessary POS tagging.
        Returns three lists, one with tokens, one with POS tagged lines, one with POS tagged sentences.
        Modules required: nltk
        '''

        # Newlines are one element of structure in the data
        # Helps limit the context and breaks up the data as is intended in resumes - i.e., into points
        lines = [el.strip() for el in document.split("\n") if len(el) > 0]  # Splitting on the basis of newlines 
        lines = [nltk.word_tokenize(el) for el in lines]    # Tokenize the individual lines
        lines = [nltk.pos_tag(el) for el in lines]  # Tag them
        # Below approach is slightly different because it splits sentences not just on the basis of newlines, but also full stops 
        # - (barring abbreviations etc.)
        # But it fails miserably at predicting names, so currently using it only for tokenization of the whole document
        sentences = nltk.sent_tokenize(document)    # Split/Tokenize into sentences (List of strings)
        sentences = [nltk.word_tokenize(sent) for sent in sentences]    # Split/Tokenize sentences into words (List of lists of strings)
        tokens = sentences
        sentences = [nltk.pos_tag(sent) for sent in sentences]    # Tag the tokens - list of lists of tuples - each tuple is (<word>, <tag>)
        # Next 4 lines convert tokens from a list of list of strings to a list of strings; basically stitches them together
        dummy = []
        for el in tokens:
            dummy += el
        tokens = dummy
        # tokens - words extracted from the doc, lines - split only based on newlines (may have more than one sentence)
        # sentences - split on the basis of rules of grammar
        return tokens, lines, sentences

# %%
a = "\n".join([el.strip() for el in f.split("\n") if len(el.strip()) > 1][0:15])

# %%
lines_names = [el.strip() for el in f.split("\n") if len(el.strip()) > 1][0:15]
lines = [nltk.word_tokenize(el) for el in lines]
lines = [nltk.pos_tag(el) for el in lines]
# Out:
# [[('94', 'CD'),
#   (',', ','),
#   ('Central', 'NNP'),
#   ('Ave', 'NNP'),
#   (',', ','),
#   ('APT', 'NNP'),
#   ('1', 'CD'),
#   (',', ',')],
#  [('Jersey', 'NNP'),
#   ('City', 'NNP'),
#   (',', ','),
#   ('NJ', 'NNP'),
#   (',', ','),
#   ('07306', 'CD')],
#  [('BHARAT', 'NNP'), ('SRI', 'NNP'), ('HARSHA', 'NNP')],
#  [('KARPURAPU', 'NNP')],
#  [('+1', 'NN'), ('(', '('), ('205', 'CD'), (')', ')'), ('200-8202', 'CD')],
#  [('kbsriharsha', 'NN'), ('@', 'CD'), ('gmail.com', 'NN')],
#  [('https', 'NN'), (':', ':'), ('//github.com/kbsriharsha/DataScience', 'NN')],
#  [('(', '('),
#   ('June', 'NNP'),
#   ('2018', 'CD'),
#   ('–', 'NNP'),
#   ('Current', 'NNP'),
#   (')', ')')],
#  [('https', 'NN'), (':', ':'), ('//www.linkedin.com/in/kbsriharsha/', 'NN')],
#  [('Seasoned', 'VBN'),
#   ('data', 'NNS'),
#   ('scientist', 'NN'),
#   ('with', 'IN'),
#   ('nearly', 'RB'),
#   ('4', 'CD'),
#   ('plus', 'JJ'),
#   ('years', 'NNS'),
#   ('of', 'IN'),
#   ('domain', 'NN'),
#   ('experience', 'NN'),
#   ('through', 'IN'),
#   ('professional', 'JJ'),
#   ('work', 'NN'),
#   ('and', 'CC'),
#   ('research', 'NN'),
#   (',', ',')],
#  [('and', 'CC'),
#   ('with', 'IN'),
#   ('demonstrated', 'JJ'),
#   ('abilities', 'NNS'),
#   ('in', 'IN'),
#   ('delivering', 'VBG'),
#   ('actionable', 'JJ'),
#   ('insights', 'NNS'),
#   ('using', 'VBG'),
#   ('advanced', 'JJ'),
#   ('data-driven', 'JJ'),
#   ('methods', 'NNS')],
#  [('Proven', 'NNP'),
#   ('credentials', 'NNS'),
#   ('in', 'IN'),
#   ('developing', 'VBG'),
#   ('and', 'CC'),
#   ('delivering', 'VBG'),
#   ('complex', 'JJ'),
#   ('business', 'NN'),
#   ('solutions', 'NNS'),
#   ('with', 'IN'),
#   ('strong', 'JJ'),
#   ('emphasis', 'NN'),
#   ('on', 'IN'),
#   ('machine', 'NN')],
#  [('learning', 'NN'),
#   (',', ','),
#   ('deep', 'JJ'),
#   ('learning', 'NN'),
#   (',', ','),
#   ('big', 'JJ'),
#   ('data', 'NN'),
#   ('analytics', 'NNS'),
#   (',', ','),
#   ('natural', 'JJ'),
#   ('language', 'NN'),
#   ('processing', 'NN'),
#   (',', ','),
#   ('statistics', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('high-performance', 'NN'),
#   ('computing', 'NN')],
#  [('Has', 'NNP'),
#   ('expert', 'JJ'),
#   ('level', 'NN'),
#   ('of', 'IN'),
#   ('knowledge', 'NN'),
#   ('in', 'IN'),
#   ('various', 'JJ'),
#   ('data', 'NNS'),
#   ('science', 'NN'),
#   ('technology', 'NN'),
#   ('platforms', 'NNS'),
#   ('and', 'CC'),
#   ('highly', 'RB'),
#   ('skilled', 'VBN'),
#   ('in', 'IN'),
#   ('orchestrating', 'VBG'),
#   ('data', 'NNS'),
#   ('from', 'IN')],
#  [('various', 'JJ'),
#   ('sources', 'NNS'),
#   ('(', '('),
#   ('on', 'IN'),
#   ('premise', 'NN'),
#   (',', ','),
#   ('cloud', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('different', 'JJ'),
#   ('vendors', 'NNS'),
#   (')', ')'),
#   ('and', 'CC'),
#   ('developing', 'VBG'),
#   ('data', 'NNS'),
#   ('driven', 'RB'),
#   ('predictive', 'JJ'),
#   ('applications', 'NNS')]]

# %%
#lines.index('PROFESSIONAL EXPERIENCE')

# %%
# !pwd
# Out:
# /Users/kbsriharsha/Documents/Education/Python/TravelersInsurance/APTS_ApplicantParsingAndTrackingSystem/notebooks

# %%
open("names.txt", "r").read().lower()
# Out:
# "sridharamurty aabha aabharana aabheer aachman aadab aadarsh aadarshini aadepu aadesh aadhira aadhya aadi aadidev aadil aadinath aadit aadita aaditeya aaditiyaa aaditya aadrika aafreen aagam aagney aagneya aahlaad aahladita aahna aahva aakanksha aakankshasaxena aakar aakarshan aakash aakriti aakruthi aakruti aalam aalap aalekh aalia aaliya aalok aaloke aamaal aamandeep aamir aamod aanand aanandan aanandswarup aanchal aandaleeb aanjaneya aaoka aapt aapti aara aaradhak aaratrika aarif aarini aariz aarna aarohi aarthi aarthy aarti aasawa aashalata aashi aashika aashish aashita aashiyana aashna aashni aashritha aasia aasim aasmaa aastha aathmika aatikah aatmaja aatreya aayu aayush aayushi aayushman abaan abani abbas abbasi abbi abdeen abdul abdul-azeez abdul-baari abdul-ghafoor abdul-hafiz abdul-hameed abdul-haseeb abdul-jabar abdul-jaleel abdul-khaliq abdul-qadir abdul-qahaar abdul-qudoos abdul-raheem abdul-raouf abdul-rasheed abdul-razaaq abdul-salaam abdul-waahid abdul-wadood abdulgafur abdulhasan abdulla abdullah abdur abed abeddin abedin abeer abha abhati abhay abhaya abhayananda abhayankar abhayaprada abheek abhi abhibhava abhicandra abhidha abhidhya abhidi abhihita abhiinandan abhijat abhijata abhijay abhijaya abhijeet abhijeeth abhijit abhijita abhijna abhijvala abhik abhilasa abhilash abhilasha abhilesh abhimand abhimani abhimanyu abhimanyusuta abhimoda abhinabhas abhinanda abhinandan abhinandana abhinatha abhinav abhinava abhinavagarwal abhinay abhinithi abhinivesh abhiprithi abhira abhiraj abhiram abhirami abhirath abhirathi abhiri abhiruchi abhirup abhirupa abhisar abhisarika abhisek abhishek abhisoka abhisri abhisumat abhisyanta abhitabh abhitha abhithi abhivadan abhivanth abhivira abhra abhrakasin abhyagni abhyankar abhyudaya abhyudita abid abidah abin abirami abishta abja abjayoni abjit ablaa abodh aboil aboli abraham abrar abrol abu abul acalapati acalendra acalesvara acanda acarya acaryanandana acaryasuta acaryatanaya acchindra achal achala achalendra achalraj achanta achar achari acharjya achary acharya achin achint achintya achira achit achla achrekar achuthakrishna achuthan achyut achyuta achyuthan acintya acira acyutaraya adah adajania adalarasu adani adari adarsh adarsha adatiya addal adeela adeep adesara adesh adeshwar adham adheer adheesh adhi adhik adhikara adhikari adhikary adhip adhipa adhir adhira adhiraj adhishree adhita adhvaryu adi adi-shakti adiga adikavi adil adinarayana adinath adipurush adishree adit aditeya aditha adithi adithyanarayanan aditi aditri aditya adityanandana adityavardhana adityaverma adivarekar adka adkar adlakha adnan adolath adrian adrija adrika adripathi adrisa adukia advait advani advay advaya advik advika adwait adwaita adway adwaya adwita adwiteya adwitiya adya aerik aeron aesha afaf afaq afeef afraa afrah afroza afsana afshana aftab afzal aga agal agamjeet agampreet agamya agarawal agarchand agarkar agarwa agarwal agarwala agarwalla agarwalmona agarwalâ  agashe agasti agastya agate agavane agboatwala agendra aggarwal aggrawal aggrwal agha aghanashini agharna aghat aghi aghosh agichani agiwal agnani agneya agnihotri agnikumara agnimitra agniprava agnishikha agnivesh agraj agrata agrawal agrawala agrawalla agrawalâ  agrawalâ\xad agre agrim agrima agriya agroyee agyeya ahalya ahamed ahan ahd ahemad ahijit ahilan ahilya ahimsa ahir ahirwar ahladita ahladitha ahlam ahlawat ahluwalia ahmad ahmed ahsan ahuja aibara aich aida aidasani aidil aidoor aijaz ailawadi ailush aiman ainapur ainesh airan airawat airen aisha aishani aishi aishvarya aishwarya aithal aiyar aja ajaa ajagandha ajai ajaib ajaipal ajala ajamil ajani ajanta ajastha ajat ajatashatru ajatshatru ajay ajaya ajaykumar ajeenkkya ajeet ajeeta ajesh aji ajinder ajinkya ajit ajita ajitabh ajitesh ajith ajmal ajmani ajmera ajoy akaldeep akalka akalkotkar akalmash akalpa akalpreet akand akane akanksha akansha akanshu akar akarsh akash akashleena akella akhil akhila akhilesh akhlesh akhtar akhter akil akila akira akkasetty akki ...

# %%
Names = open("first_names.txt", "r").read().lower()
set(Names.split('\n'))
# Out:
# {'dolline',
#  'anisjon',
#  'lizsandra',
#  'irit',
#  'lizzeth',
#  'raeyonna',
#  'arundhati',
#  'feriz',
#  'hara',
#  '',
#  'adosinda',
#  'airalynn',
#  'foushee',
#  'juweriya',
#  'kiminori',
#  'aizo',
#  'plows',
#  'jefferson-chisolm',
#  'jabina',
#  'muath',
#  'sieria',
#  'jeriann',
#  'mastranunzio',
#  'sherrl',
#  'ashton-lee',
#  'sayema',
#  'vladilena',
#  'zequan',
#  'svanur',
#  'aleezah-imaan',
#  'arilene',
#  'fer',
#  'tanvir',
#  'abrakata',
#  'lauralyn',
#  'ronaldas',
#  'konstanze',
#  'paizlie',
#  'kort',
#  'nesti',
#  'mmasichukwu',
#  'breylee',
#  'rutt',
#  'tabari',
#  'modica',
#  'averill',
#  'jochbed',
#  'granderson',
#  'grigol',
#  'jazmine',
#  'kelaya',
#  'cortlan',
#  'líney',
#  'rylah',
#  'ökkeş',
#  'blaju',
#  'odab',
#  'shawnic',
#  'taylor-john',
#  'calvino',
#  'zacchary',
#  'maicie-lee',
#  'bondon',
#  'andréanne',
#  'beatrix',
#  'krustjo',
#  'rayansh',
#  'delaughter',
#  'karra',
#  'reisman',
#  'janeily',
#  'ebadur',
#  'mystica',
#  'dairus',
#  'macilynn',
#  'hadubert',
#  'salene',
#  'candiece',
#  'dyland',
#  'kewin',
#  'cleante',
#  'orral',
#  'nyleah',
#  'namiyah',
#  'indigo',
#  'jewgenij',
#  'quilling',
#  'skylene',
#  'tham',
#  'laurale',
#  'tylerjohn',
#  'rethel',
#  'yvelan',
#  'derron',
#  'bridjette',
#  'keirah',
#  'lusio',
#  'jiquez',
#  'nisson',
#  'basham',
#  'reighn',
#  'chalonda',
#  'jaiyden',
#  'nakhyla',
#  'shewmaker',
#  'alayziah',
#  'adaobi',
#  'correia',
#  'sweer',
#  'addiena',
#  'nyana',
#  'aharn',
#  'sohil',
#  'ysacor',
#  'thirunavukarasu',
#  'fallan',
#  'baeza',
#  'bla\x9ako',
#  'delyana',
#  'eror',
#  'collayer',
#  'nalla',
#  'ellette',
#  'freimuth',
#  'maged',
#  'pirozzi',
#  'promisse',
#  'reaksmey',
#  '\x8atěpán',
#  'roleson',
#  'annaliyah',
#  'denécia',
#  'harsh',
#  'machuca',
#  'müslüm',
#  'bekelja',
#  'helvi',
#  'dockins',
#  'macheala',
#  'meoshia',
#  'rall',
#  'suvikki',
#  'nirutma',
#  'terronda',
#  'remmy',
#  'counterman',
#  'najier',
#  'vinston',
#  'bhav',
#  'fitton',
#  'deilkes',
#  'cailee',
#  'jeryme',
#  'jempson',
#  'amber-jayne',
#  'kenslei',
#  'keron',
#  'berish',
#  'kayshon',
#  'abrina',
#  'fortis',
#  'kofoworola',
#  'abigailgrace',
#  'sankar',
#  'lohgan',
#  'vendel',
#  'zeana',
#  'bartmann',
#  'jerrae',
#  'dewane',
#  'akeda',
#  'nayte',
#  'denamarie',
#  'castiglione',
#  'romiah',
#  'albirdia',
#  'labeeb',
#  'iveta',
#  'myquisha',
#  'weona',
#  'kenisha',
#  'barmore',
#  'ainhara',
#  'matyson',
#  'osana',
#  'dontrel',
#  'zim',
#  'laila-grace',
#  'keidon',
#  'pemela',
#  'hagi',
#  'brynlyn',
#  'dason',
#  'qiong',
#  'solveig',
#  'decario',
#  'hayleah',
#  'abbie-jane',
#  'braxtin',
#  'muthukumar',
#  'sicely',
#  'lovorko',
#  'zishan',
#  'prynceton',
#  'gerd',
#  'iyaas',
#  'wilser',
#  'isiaah',
#  'ervehe',
#  'evanni',
#  'litia',
#  'randeisha',
#  'malvine',
#  'blaklie',
#  'sivathasa',
#  'cyna',
#  'mistie',
#  'mirrin',
#  'corion',
#  'krail',
#  'finntan',
#  'lucila',
#  'danyiel',
#  'vidish',
#  'zadah',
#  'rettig',
#  'giffard',
#  'dandridge',
#  'yolette',
#  'jetsyn',
#  'immanuel',
#  'kataleia',
#  'diarmuid',
#  'mya-louise',
#  'caitlyn-rose',
#  'utopia',
#  'sylvana',
#  'onoria',
#  'ramvilash',
#  'emiljana',
#  'windie',
#  'carmela',
#  'levett',
#  'jordinn',
#  'devanhi',
#  'lachanda',
#  'goins',
#  'llulisa',
#  'tahara',
#  'karaya',
#  'buettner',
#  'bumber',
#  'trione',
#  'myrikal',
#  'arooj',
#  'luisa',
#  'neculaiu',
#  'sametta',
#  'sraar',
#  'hávarður',
#  'zanique',
#  'aniya',
#  'sanavvar',
#  'marchal',
#  'katleen',
#  'nuncio',
#  'zhian',
#  'larrera',
#  'rihanne',
#  'esain',
#  'günsel',
#  'tia-may',
#  'marnique',
#  'hurd',
#  'iashod',
#  'faggett',
#  'alleya',
#  'tidwellii',
#  'yair',
#  'ndunamiwe',
#  'joziah',
#  'kiristen',
#  'liggitt',
#  'demier',
#  'raybert',
#  'romaldo',
#  'thora',
#  'loganne',
#  'kiela',
#  'earl',
#  'zeily',
#  'weert',
#  'nshima',
#  'latechia',
#  'filias',
#  'chesterine',
#  'dazire',
#  'uros',
#  'gesemyer',
#  'alajuwon',
#  'heilke',
#  'chernyo',
#  'madelynne',
#  'lavetta',
#  'hatsumi',
#  'malkeet',
#  'naszire',
#  'desroses',
#  'charma',
#  'farisha',
#  'corton',
#  'devra',
#  'ebraheem',
#  'gerbrand',
#  'shadric',
#  'tatum',
#  'shawntee',
#  'hakop',
#  'javaris',
#  'florane',
#  'jerrick',
#  'keystle',
#  'antonious',
#  'lotten',
#  'elizabeth-rose',
#  'hak',
#  'betsy-bo',
#  'jenisha',
#  'jeremey',
#  'muhammad-bilal',
#  'hailena',
#  'seigler',
#  'klark',
#  'chrystene',
#  'cylan',
#  'roopal',
#  'aroz',
#  'lynnie',
#  'eustasius',
#  'ilah',
#  'carmello',
#  'tugdual',
#  'yda',
#  'amye',
#  'paige',
#  'svetljo',
#  'elha',
#  'alexander-junior',
#  'christopoher',
#  'barger',
#  'montenegro',
#  'kinsasha',
#  'colista',
#  'kylise',
#  'fidel',
#  'amylea',
#  'nelams',
#  'fahy',
#  'ştefania',
#  'dharampal',
#  'deneshia',
#  'karmynn',
#  'anyelo',
#  'nilah',
#  'davaughn',
#  'phanuel',
#  'futch',
#  'sherria',
#  'valma',
#  'imaani',
#  'jameka',
#  'janetlee',
#  'tyrika',
#  'yerli',
#  'kyla-mae',
#  'leigh-marie',
#  'mordy',
#  'amberlee',
#  'ateeqa',
#  'ligonde',
#  'easley',
#  'ayza',
#  'fidellia',
#  'jandirk',
#  'amazigh',
#  'melaniya',
#  'jordynne',
#  'fidelina',
#  'haseeba',
#  'ferid',
#  'ziyi',
#  'caporal',
#  'devereux',
#  'shadeja',
#  'onawa',
#  'arkadius',
#  'bergess',
#  'jaleh',
#  'jalaysha',
#  'nazmeen',
#  'desaun',
#  'sievert',
#  'dagbjört',
#  'filotita',
#  'franceen',
#  'nashyia',
#  'lynae',
#  'niyla',
#  'pantalone',
#  'rebecca-rose',
#  'antavia',
#  'izell',
#  'cohette',
#  'jaime-lee',
#  'kowlessar',
#  'lmer',
#  'naşit',
#  'oglesbee',
#  'cuiksa',
#  'sharusan',
#  'woodroe',
#  'timmothy',
#  'devari',
#  'neriya',
#  'danley',
#  'munehito',
#  'glwadys',
#  'rosado-perez',
#  'lucymarie',
#  'tiarah',
#  'zoela',
#  'rieky',
#  'amedee',
#  'lykan',
#  'kalandra',
#  'binford',
#  'zackariyah',
#  'luzette',
#  'charlise',
#  'lebert',
#  'kyonna',
#  'sevi',
#  'annagh',
#  'holybrice',
#  'abran',
#  'dreighton',
#  'begoña',
#  'elijahh',
#  'wachovia',
#  'ahlayah',
#  'germut',
#  'marlit',
#  'sunnat',
#  'sylejman',
#  'iosua',
#  'halle',
#  'jahmar',
#  'amaurion',
#  'ehlana',
#  'engelhardt',
#  'harliegh',
#  'malala',
#  'tess',
#  'andjoua',
#  'peretz',
#  'meghen',
#  'joevany',
#  'mercedes',
#  'partha',
#  'joscelyne',
#  'andreacchio',
#  'emris',
#  'miguelita',
#  'moffit',
#  'simphiwe',
#  'hemphill',
#  'pārsla',
#  'yee',
#  'daran',
#  'ariadne',
#  'aurkene',
#  'shiwani',
#  'dulina',
#  'şafak',
#  'lameria',
#  'calam',
#  'lemay',
#  'twiggy',
#  'tylik',
#  'elene',
#  'raenell',
#  'violanda',
#  'teeghan',
#  'anney',
#  'jumaane',
#  'mite',
#  'salomn',
#  'ioseph',
#  'esven',
#  'audrielle',
#  'obama',
#  'brendalynn',
#  'braegan',
#  'scharf',
#  'anette',
#  'deajah',
#  'muhammadali',
#  'rudean',
#  'camon',
#  'noellyn',
#  'fortes-diaz',
#  'notburga',
#  'chelsy',
#  'edim',
#  'shehide',
#  'steph',
#  'elrick',
#  'jūlija',
#  'denys',
#  'chanice',
#  'dearria',
#  'kanav',
#  'koralle',
#  'aliani',
#  'liudas',
#  'yoshica',
#  'daileigh',
#  'karoliina',
#  'natusha',
#  'rondle',
#  'pharisien',
#  'sheveal',
#  'taleigh',
#  'rondre',
#  'alphard',
#  'jumalay',
#  'sinclair',
#  'ponnampalam',
#  'jonko',
#  'ineda',
#  'riekje',
#  'svanbjörn',
#  'abott',
#  'nicolasa',
#  'rojean',
#  'jadarrious',
#  'salmonson',
#  'shaketra',
#  'cristofor',
#  'poliana',
#  'shalei',
#  'jens',
#  'eleanar',
#  'gayner',
#  'hasson',
#  'shamise',
#  'sitora',
#  'ajalon',
#  'treco',
#  'carmynn',
#  'bernan',
#  'zenone',
#  'ava-jade',
#  'anessa',
#  'maximes',
#  'clellan',
#  'boles',
#  'pompilian',
#  'gabriyel',
#  'arethea',
#  'agerton',
#  'wynonia',
#  'eunike',
#  'jaysea',
#  'astare',
#  'olugbenga',
#  'litsa',
#  'daleia',
#  'zion-cole',
#  'sperling',
#  'berhley',
#  'kelvin',
#  'kuhlmann',
#  'bowermaster',
#  'barlina',
#  'javarri',
#  'stevie-mae',
#  'tulisa-marie',
#  'bobbijo',
#  'isobell',
#  'roslind',
#  'tianie',
#  'manfredonia',
#  'derdine',
#  'kallee',
#  'suhailah',
#  'latinya',
#  'tallant',
#  'ethanial',
#  'shekera',
#  'sebrinia',
#  'dunkum',
#  'manpritkour',
#  'adilkhan',
#  'mélodie',
#  'demodena',
#  'colin-junior',
#  'rudie',
#  'bonilla-flores',
#  'whittnie',
#  'snædís',
#  'shrivika',
#  'karlik',
#  'wigdis',
#  'matthewjames',
#  'cherry-leigh',
#  'deavan',
#  'barnabé',
#  'bérenger',
#  'sertaç',
#  'hajri',
#  'ty-reece',
#  'climpson',
#  'keevah-lee',
#  'marshaya',
#  'leeandra',
#  'muhammad-walcott',
#  'gooch',
#  'siegfred',
#  'deldra',
#  'josianna',
#  'talullah',
#  'yamari',
#  'okka',
#  'mikaylyn',
#  'remon',
#  'tanishk',
#  'georgeanne',
#  'oursler',
#  'erand',
#  'lakhdar',
#  'ackler',
#  'lena',
#  'madelane',
#  'shamonte',
#  'charlieann',
#  'aaronjosh',
#  'kialie',
#  'alyssum',
#  'lonesha',
#  'shauntele',
#  'snya',
#  'selah',
#  'wellman',
#  'trevionne',
#  'rikard',
#  'kimberlin',
#  'drina',
#  'araiza',
#  'tarry',
#  'jaggyr',
#  'merat',
#  'riquel',
#  'terryon',
#  'lovelace',
#  'ambrósio',
#  'aleeshba',
#  'atreyu',
#  'sophia-may',
#  'berger',
#  'careen',
#  'tieisha',
#  'zorion',
#  'ena',
#  'correa-guadarrama',
#  'molloy',
#  'aguste',
#  'gracieann',
#  'mkhitar',
#  'reyla',
#  'jawed',
#  'grafals',
#  'rafn',
#  'kevern',
#  'surber',
#  'perez-huizache',
#  'yaqub',
#  'sawana',
#  'magdeline',
#  'araiya',
#  'calle-arboleda',
#  'houria',
#  'jaredd',
#  'yakisha',
#  'joziel',
#  'swec',
#  'minija',
#  'yury',
#  'iree',
#  'dündar',
#  'treasea',
#  'dazya',
#  'kahne',
#  'deonni',
#  'mairah',
#  'maun',
#  'averi',
#  'omor',
#  'riles',
#  'shereka',
#  'sudesh',
#  'merisier',
#  'karsan',
#  'cybele',
#  'jessical',
#  'sanari',
#  'rosmeri',
#  'aarielle',
#  'kelmend',
#  'timberleigh',
#  'cvetelina',
#  'lumir',
#  'yentel',
#  'shaneen',
#  'rrustem',
#  'winrich',
#  'marleyjane',
#  'emelie',
#  'alyson',
#  'raylee',
#  'zykira',
#  'heins',
#  'ehan',
#  'lino',
#  'chabely',
#  'firuţa',
#  'hinderich',
#  'nevaeh-marie',
#  'rabadan',
#  'sahvana',
#  'meshell',
#  'lowrine',
#  'lafrance',
#  'carlester',
#  'ilma',
#  'montea',
#  'sebatian',
#  'huynh',
#  'dorli',
#  'aniket',
#  'hamberg',
#  'hinke',
#  'friedsam',
#  'mcclister',
#  'nahama',
#  'hanswolf',
#  'leilanis',
#  'jere',
#  'sabrie',
#  'bratton',
#  'deetya',
#  'jannery',
#  'efigénia',
#  'mary-jayne',
#  'sabīne',
#  'sanjan',
#  'sopho',
#  'aristida',
#  'ciarra',
#  'derck',
#  'joacimah',
#  'aufmann',
#  'mincher',
#  'oghenegaren',
#  'sevtap',
#  'montel',
#  'kasam',
#  'vines',
#  'mallely',
#  'mawaddah',
#  'cielita',
#  'shaelea',
#  'dana',
#  'prashansa',
#  'hashley',
#  'harmanjit',
#  'polette',
#  'felicio',
#  'geordan',
#  'tygan',
#  'kallai',
#  'baca',
#  'dennen',
#  'krystn',
#  'rosario-andino',
#  'dearron',
#  'gaddis',
#  'mecca',
#  'reando',
#  'napoles',
#  'sadea',
#  'kunin',
#  'sergeja',
#  'addlynn',
#  'thaddeous',
#  'cleodell',
#  'xeniyah',
#  'gaini',
#  'trypp',
#  'taleena',
#  'bafti',
#  'nuriel',
#  'castel',
#  'camerron',
#  'georgeanthony',
#  'aneliese',
#  'doval',
#  'jaymarie',
#  'thevenot',
#  'laurielle',
#  'mckaylen',
#  'bleron',
#  'hannlenie',
#  'jahmere',
#  'erwin',
#  'inmer',
#  'miceal',
#  'tahtianna',
#  'nugzar',
#  'stace',
#  'drape',
#  'pamm',
#  'yazn',
#  'greenly',
#  'jarron',
#  'danaira',
#  'dakukubie',
#  'mushtak',
#  'wylko',
#  'clione',
#  'liodegario',
#  'ortrude',
#  'constancio',
#  'danyluk',
#  'deralyn',
#  'mireles',
#  'sank',
#  'parlin',
#  'verdie',
#  'rashamel',
#  'cattan',
#  'léandre',
#  'carell',
#  'pankratz',
#  'amida',
#  'ember',
#  'guindin',
#  'annazette',
#  'ignatius',
#  'kipp',
#  'dunc',
#  'nuvia',
#  'redonda',
#  'byes',
#  'honorio',
#  'pavlína',
#  'casey-ray',
#  'ladre',
#  'trif',
#  'grozda',
#  'gulshara',
#  'margus',
#  'garay',
#  'bayete',
#  'selba',
#  'adrieana',
#  'ruocco',
#  'austin',
#  'alhasan',
#  'daqwane',
#  'michael',
#  'moshood',
#  'yaleni',
#  'danny-james',
#  'zebra',
#  'marianella',
#  'michaelangel',
#  'honeter',
#  'shardia',
#  'tanno',
#  'maggese',
#  'aurélien',
#  'yonni',
#  'daschel',
#  'monds',
#  'beşir',
#  'isaiah',
#  'schane',
#  'allyna',
#  'lubna',
#  'soltanica',
#  'ivell',
#  'blocker',
#  'yalisa',
#  'snellbaker',
#  'chikenumkeka',
#  'kiyami',
#  'sellathurai',
#  'vulnavia',
#  'kshon',
#  'andromeda',
#  'ruksaar',
#  'hikmah',
#  'zebulah',
#  'droplaug',
#  'dziadon',
#  '\x8aerif',
#  'matheny',
#  'nungester',
#  'nyiema',
#  'janise',
#  'jurem',
#  'makinzie',
#  'meshah',
#  'milano',
#  'morningstar',
#  'munera',
#  'katrina',
#  'percival',
#  'presentación',
#  'roshika',
#  'zema',
#  'gizelle',
#  'analya',
#  'firdous',
#  'karansingh',
#  'leihla',
#  'bentzy',
#  'jhamar',
#  'liwsi',
#  'summie',
#  'vuto',
#  'luthando',
#  'astra',
#  'hery',
#  'jiren',
#  'nieburg',
#  'ardak',
#  'dafydd',
#  'pinhas',
#  'kristjaana',
#  'sameep',
#  'harpole',
#  'carly',
#  'libby-jane',
#  'luděk',
#  'razije',
#  'alishba',
#  'emmoni',
#  'honi',
#  'christophel',
#  'sabahudin',
#  'jacquise',
#  'bollig',
#  'calder',
#  'katherene',
#  'kostanty',
#  'upton',
#  'yulene',
#  'qamari',
#  'arnþór',
#  'cyrgalis',
#  'ruxhdi',
#  'jaila',
#  'moreen',
#  'baani',
#  'leverta',
#  'qëndresa',
#  'shelbye',
#  'justinas',
#  'liher',
#  'haadiyah',
#  'anthani',
#  'kristy',
#  'manali',
#  'mortie',
#  'riffat',
#  'syndy',
#  'teshawn',
#  'zakhir',
#  'dannii-leigh',
#  'iliah',
#  'addiel',
#  'jaiah',
#  'vilfredo',
#  'ilariu',
#  'amelia-skye',
#  'lavern',
#  'dejanai',
#  'manshuk',
#  ...}

# %%
def modified(inputString, debug=False):
        '''
        Given an input string, returns possible matches for names. Uses regular expression based matching.
        Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
        Modules required: clock from time, code.
        '''

        # Reads Indian Names from the file, reduce all to lower case for easy comparision [Name lists]
        indianNames = open("first_names.txt", "r").read().lower()
        # Lookup in a set is much faster
        indianNames = set(indianNames.split('\n'))
        otherNameHits = []
        nameHits = []
        name = None
        try:
            tokens, lines, sentences = preprocess(inputString)
            grammar = r'NAME: {<NN.*><NN.*><NN.*><NN.*>*}'
            chunkParser = nltk.RegexpParser(grammar)
            all_chunked_tokens = []
            for tagged_tokens in lines:
                if len(tagged_tokens) == 0: continue # Prevent it from printing warnings
                chunked_tokens = chunkParser.parse(tagged_tokens)
                all_chunked_tokens.append(chunked_tokens)
                for subtree in chunked_tokens.subtrees():
                    if subtree.label() == 'NAME':
                        for ind, leaf in enumerate(subtree.leaves()):
                            if leaf[0].lower() in indianNames and 'NN' in leaf[1]:
                                hit = " ".join([el[0] for el in subtree.leaves()[ind:ind+3]])
                                if re.compile(r'[\d,:]').search(hit): continue
                                nameHits.append(hit)
            if len(nameHits) > 0:
                nameHits = [re.sub(r'[^a-zA-Z \-]', '', el).strip() for el in nameHits] 
                name = " ".join([el[0].upper()+el[1:].lower() for el in nameHits[0].split() if len(el)>0])
                otherNameHits = nameHits[1:]

        except Exception as e:
            print(e)      

        print(name)
        return name, otherNameHits

# %%
f = convertPDFToText("Resume_Harsha_Updated.pdf")

# %%
modified(f)
# Out:
# Bharat Sri Harsha
# ('Bharat Sri Harsha',
#  ['SRI HARSHA', 'HARSHA', 'New York Life', 'New York City'])

# %%
def getName(inputString, debug=False):
        '''
        Given an input string, returns possible matches for names. Uses regular expression based matching.
        Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
        Modules required: clock from time, code.
        '''

        # Reads Indian Names from the file, reduce all to lower case for easy comparision [Name lists]
        indianNames = open("names.txt", "r").read().lower()
        # Lookup in a set is much faster
        indianNames = set(indianNames.split())
        otherNameHits = []
        nameHits = []
        name = None
        try:
            tokens, lines, sentences = preprocess(inputString)
            grammar = r'NAME: {<NN.*><NN.*><NN.*><NN.*>*}'
            chunkParser = nltk.RegexpParser(grammar)
            all_chunked_tokens = []
            for tagged_tokens in lines:
                if len(tagged_tokens) == 0: continue # Prevent it from printing warnings
                chunked_tokens = chunkParser.parse(tagged_tokens)
                all_chunked_tokens.append(chunked_tokens)
                for subtree in chunked_tokens.subtrees():
                    if subtree.label() == 'NAME':
                        for ind, leaf in enumerate(subtree.leaves()):
                            if leaf[0].lower() in indianNames and 'NN' in leaf[1]:
                                hit = " ".join([el[0] for el in subtree.leaves()[ind:ind+3]])
                                if re.compile(r'[\d,:]').search(hit): continue
                                nameHits.append(hit)
            if len(nameHits) > 0:
                nameHits = [re.sub(r'[^a-zA-Z \-]', '', el).strip() for el in nameHits] 
                name = " ".join([el[0].upper()+el[1:].lower() for el in nameHits[0].split() if len(el)>0])
                otherNameHits = nameHits[1:]

        except Exception as e:
            print(traceback.format_exc())
            print(e)      

        print(name)
        return name, otherNameHits

# %%
getName()
# Out:
# Naval Academy
# ('Naval Academy',
#  ['Engineer',
#   'Deep Sea Diver',
#   'Engineer Corps Officer',
#   'Engineer',
#   'Naval facilities',
#   'Naval facilities',
#   'Engineer Corps Officer'])

# %%
from nltk.tag.stanford import StanfordNERTagger

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

# %%
re.sub("\n\n", "\n", f)
# Out:
# '94, Central Ave, APT 1, \nJersey City, NJ, 07306 \nBHARAT SRI HARSHA \nKARPURAPU \n+1 (205) 200-8202 \nkbsriharsha@gmail.com \n \nhttps://github.com/kbsriharsha/DataScience \n(June 2018 – Current) \nhttps://www.linkedin.com/in/kbsriharsha/ \n  \nSeasoned data scientist with nearly 4 plus years of domain experience through professional work and research, \n \nand with demonstrated abilities in delivering actionable insights using advanced data-driven methods \n \nProven credentials in developing and delivering complex business solutions with strong emphasis on machine \n \nlearning, deep learning, big data analytics, natural language processing, statistics, and high-performance computing \n \nHas expert level of knowledge in various data science technology platforms and highly skilled in orchestrating data from \nvarious sources (on premise, cloud, and different vendors) and developing data driven predictive applications \n \n \nPROFESSIONAL EXPERIENCE \n \n \nNew York Life Insurance – New York City, NY \n \nSenior Associate, Data Science \n \n- Functioning as one of the data experts and tech liaisons of the team assigned to curate, design, and develop the \nmodel ready data sets and introduce the latest cutting edge algorithms and platforms for increased computation \nspeed and accuracy \n \n- Successfully designed and implemented a process for cleaning the unstructured beneficiary records \nusing Natural Language Processing techniques and saved 2 million$ vendor cost \n \n- Creating model ready dataset (MRD) for agent compliance model; which is aimed to classify the non-compliant \nvs compliant agents as per the NYL rules \n \nRegions Bank – Birmingham, AL \n \nData Scientist (June 2017 – May 2018) \nData Scientist Intern (Jan 2016 – May 2017) \n \n- Part of the new data science team (4 members) created under the CDO (Chief Data Officer) for developing \npredictive analytics and augmented intelligence applications to help the bank in process improvement and for finding \nnew opportunities \n \n- As a team, assigned to create and architect an enterprise big data environment with Hadoop echo system and IBM \nPower Minskey (Nvidia P100 GPU’s) to facilitate data science team and quant squad in the bank \n \n- Successfully  developed  applications  like  Intelligent  Web  Scrapper  for  getting  information  on  potential  customers \nfrom the web, Regions Business Universe which facilitates various departments of the bank to take quick customer \ndecisions and contributed in delivering quick process for CIP (Customer Identification Program) which decrease the \nprocess time from 20 min to 3 min \n \n- Acted as lead role for determining the POCO (Probability of Charge-off) for an overdraft account, and replaced the \n \nold model with the new model with 4% increase in accuracy. \n \n \nEDUCATION \n \n \nUniversity of Alabama at Birmingham (Master’s Degree) \n \nElectrical and Computer Engineering Dept. (Data Science Concentration) (G.P.A: 4.0) \n \nResearch Fields: Machine Learning, Deep Learning, Big Data Analytics, Natural Language Processing, and High \nPerformance Computing \n \nThesis Title: Framework for Social Network Sentiment Analysis Using Big Data Analytics \n \n- Developed a generalized framework for performing social network sentiment analysis on any kind of domain \nsuch as automobile, banking and telecom \n \n- Studied numerous research papers on natural language processing, big data analytics and machine learning \n \n \nPublication: Big Data and Visual Analytics, Springer 2017, Chapter 12, Page: 203-218 \n* Case Study: Automobile * Popular: BMW * Highest Sentiment: Mercedes (0.87) * Lowest Sentiment: Buick(0.49) \n(Jan 2016 –May 2018) \n(Aug 2015 – April 2017) \n\x0c'

# %%
valid_text = '''
Bharat Sri Harsha Karpurapu \n
Seasoned data scientist with nearly 4 plus years of domain experience through professional work and research, 
and with demonstrated abilities in delivering actionable insights using advanced data-driven methods  
Proven credentials in developing and delivering complex business solutions with strong emphasis on machine  learning, 
deep learning, big data analytics, natural language processing, statistics, and high-performance computing  Has expert level of knowledge in various data science technology platforms and highly skilled in orchestrating data 
from various sources (on premise, cloud, and different vendors) and developing data driven predictive applications   
'''

# %%
def extract_entities(text):
    for sent in nltk.sent_tokenize(text):
        for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
            if hasattr(chunk, 'label'):
                print(chunk.label()+' '.join(c[0] for c in chunk.leaves()))

# %%
a = [el.strip() for el in f.split("\n") if len(el.strip()) > 1]

# %%
lines = [nltk.word_tokenize(el) for el in a]
[nltk.pos_tag(el) for el in lines]
# Out:
# [[('Managing', 'VBG'),
#   ('Partner', 'NNP'),
#   ('and', 'CC'),
#   ('Program', 'NNP'),
#   ('Manager/Engineer', 'NNP')],
#  [('Erick', 'NNP'), ('B.', 'NNP'), ('Knezek', 'NNP')],
#  [('Education', 'NN')],
#  [('\uf0a7', 'JJ'),
#   ('B.S.', 'NNP'),
#   (',', ','),
#   ('Ocean', 'NNP'),
#   ('Engineering', 'NNP'),
#   (',', ','),
#   ('United', 'NNP')],
#  [('States', 'NNS'),
#   ('Naval', 'NNP'),
#   ('Academy', 'NNP'),
#   (',', ','),
#   ('1996', 'CD')],
#  [('\uf0a7', 'JJ'),
#   ('M.S.', 'NNP'),
#   (',', ','),
#   ('Ocean', 'NNP'),
#   ('Engineering', 'NNP'),
#   (',', ','),
#   ('Texas', 'NNP'),
#   ('A', 'NNP')],
#  [('&', 'CC'), ('M', 'NNP'), (',', ','), ('1997', 'CD')],
#  [('Years', 'NNS'),
#   ('of', 'IN'),
#   ('Experience', 'NNP'),
#   ('-', ':'),
#   ('18', 'CD')],
#  [('Professional', 'NNP'), ('Engineer', 'NNP')],
#  [('Maryland', 'NNP'), (',', ',')]]

# %%
extract_entities(a)
# Out:
# PERSONPartner
# PERSONProgram
# PERSONErick B. Knezek Education
# PERSONOcean Engineering
# GPEUnited States
# PERSONNaval Academy
# PERSONOcean Engineering
# PERSONTexas
# GPEExperience
# GPEMaryland

# %%
for sent in nltk.sent_tokenize(valid_text):
    print(sent)
# Out:
# Bharat Sri Harsha Karpurapu
#
# Seasoned data scientist with nearly 4 plus years of domain experience through professional work and research,
# and with demonstrated abilities in delivering actionable insights using advanced data-driven methods
# Proven credentials in developing and delivering complex business solutions with strong emphasis on machine  learning,
# deep learning, big data analytics, natural language processing, statistics, and high-performance computing  Has expert level of knowledge in various data science technology platforms and highly skilled in orchestrating data
# from various sources (on premise, cloud, and different vendors) and developing data driven predictive applications

# %%
f = convertPDFToText('resume_trail2.pdf')

# %%
a = [el.strip() for el in f.split("\n") if len(el.strip()) > 1]

# %%
from pyresparser import ResumeParser
ResumeParser('resume_trail2.pdf').get_extracted_data()
# Out:
# {'name': 'Milton Village',
#  'email': None,
#  'mobile_number': None,
#  'skills': ['Supervising',
#   'Safety',
#   'Access',
#   'Retail',
#   'Administration',
#   'Process',
#   'Supervisor',
#   'Construction'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': None,
#  'company_names': None,
#  'no_of_pages': 2,
#  'total_experience': 0}

# %%
a
# Out:
# 'Managing Partner and Program Manager/Engineer\nErick B. Knezek\nEducation\n\uf0a7  B.S., Ocean Engineering, United\nStates Naval Academy, 1996\n\uf0a7  M.S., Ocean Engineering, Texas A\n& M, 1997\nYears of Experience - 18\nProfessional Engineer\nMaryland,\nQualified Navy Deep Sea Diver\nand Dive Supervisor\nRELEVANT EXPERIENCE\nMr.  Knezek  has  more  than  18  years  of  program/technical\nmanagement,  civil  and  ocean  engineering,  and  construction'

# %%
expertises = open("expertise.txt", "r").read().lower()
        # Lookup in a set is much faster
expertises = set(expertises.split())

# %%
b = dict([(x, float(nlp(x).similarity(nlp("\n".join(a))))) for x in expertises])

# %%
max(b, key = lambda x: x[1])
# Out:
# '"vascularsurgeon"'

# %%
b
# Out:
# {'"psychology"': 0.45530620914098646,
#  '"firecause&analysis"': 0.3171480422576838,
#  '"maritime"': 0.4513871834444972,
#  '"stockmarketactivities"': 0.3171480422576838,
#  '"ballistics&firearms"': 0.3171480422576838,
#  '"forensicpathologist"': 0.3171480422576838,
#  '"computersoftware"': 0.3171480422576838,
#  '"physical': 0.5424624555387254,
#  '"safetyengineer"': 0.3171480422576838,
#  '"orthopedist"': 0.44227747638288895,
#  '"urology"': 0.433445295994399,
#  '"generalsurgeon"': 0.3171480422576838,
#  '"electricalengineer"': 0.3171480422576838,
#  '"environmentalengineer"': 0.3171480422576838,
#  '"fingerprint"': 0.46384245732990304,
#  '"hospitaladministration"': 0.3171480422576838,
#  '"economist"': 0.3523900444536046,
#  '"lifecareplanner"': 0.3171480422576838,
#  '"pharmicologist"': 0.3171480422576838,
#  '"civilengineer"': 0.3171480422576838,
#  '"insurance"': 0.52566960807242,
#  '"realpropertyappraiser"': 0.3171480422576838,
#  '"slips&falls&cof"': 0.3171480422576838,
#  '"osha"': 0.38656155157025035,
#  '"internalmedicine"': 0.3171480422576838,
#  '"cardiothoracicsurgeon"': 0.3171480422576838,
#  '"endocrinology"': 0.3932555237783013,
#  '"chiropractor"': 0.4302304305687618,
#  '"mechanicalengineer"': 0.3171480422576838,
#  '"documentexaminer"': 0.3171480422576838,
#  '"opthalmologist"': 0.37243291966763237,
#  '"humanfactorsengineer"': 0.3171480422576838,
#  '"hydrology"': 0.40176132326053604,
#  '"hvac"': 0.4174379901925808,
#  '"humanresourcemanagement"': 0.3171480422576838,
#  '"physiciansassistant"': 0.3171480422576838,
#  '"anesthesiology"': 0.46904224170585573,
#  '"foodsafety"': 0.3171480422576838,
#  '"legalnurseconsultant"': 0.3171480422576838,
#  '"neurosurgeon"': 0.44227747638288895,
#  '"publichealth"': 0.3171480422576838,
#  '"accounting"': 0.510452039459232,
#  '"computerhardware"': 0.3171480422576838,
#  '"banking"': 0.4836869822517815,
#  '"statistician"': 0.40833472040431357,
#  '"bloodanalysis"': 0.3171480422576838,
#  '"pharmacist"': 0.46904224170585573,
#  '"chemicalengineer"': 0.3171480422576838,
#  '"neurologist"': 0.37243291966763237,
#  '"policeprocedures"': 0.3171480422576838,
#  '"pediatrics"': 0.47518226709786954,
#  '"radiology"': 0.5421404317442746,
#  '"vascularsurgeon"': 0.3171480422576838,
#  '"emergencyroom"': 0.3171480422576838,
#  '"general&familypractice"': 0.3171480422576838,
#  '"machinesafety&guarding"': 0.3171480422576838,
#  '"computersecurity"': 0.3171480422576838,
#  '"elevator"': 0.4252322709606447,
#  '"oncology"': 0.47380889822782524,
#  '"finance"': 0.5160757985928411,
#  '"operatingroomnurse"': 0.3171480422576838,
#  'therapy"': 0.4624712015293551,
#  '"pulmonarymedicine"': 0.3171480422576838,
#  '"structuralengineer"': 0.3171480422576838,
#  '"architect"': 0.4757779556007364,
#  '"biomedicalengineer"': 0.3171480422576838,
#  '"industrialengineer"': 0.3171480422576838,
#  '"psychiatry"': 0.4217224372043151,
#  '"dermatologist"': 0.44227747638288895,
#  '"toxicologist"': 0.36706114077241686,
#  '"agriculturalengineer"': 0.3171480422576838,
#  '"highwaydesign&construction"': 0.3171480422576838,
#  '"recreationalsafety"': 0.3171480422576838,
#  '"industrialhygiene"': 0.3171480422576838,
#  '"ob&gyn"': 0.3171480422576838,
#  '"cardiologist"': 0.44227747638288895,
#  '"ent&allergist"': 0.3171480422576838,
#  '"generaldentistry"': 0.3171480422576838,
#  '"automotiveengineer"': 0.3171480422576838,
#  '"paramedic"': 0.43342053073528264,
#  '"materialsengineer"': 0.3171480422576838,
#  '"orthopedicsurgeon"': 0.3171480422576838}

# %%
import spacy
nlp = spacy.load('en_core_web_md')
doc1 = nlp('DocumentExaminer')
doc2 = nlp("\n".join(a))
#doc3 = nlp(u'Hey whatsup?')

print (doc1.similarity(doc2)) # 0.999999954642
#print doc2.similarity(doc3) # 0.699032527716
#print doc1.similarity(doc3)
# Out:
# 0.0
# /Users/kbsriharsha/anaconda3/lib/python3.6/runpy.py:193: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   "__main__", mod_spec)
