# %%
# importing libraries
import re
import pyap

# %%
txt = "this is spain"

EMAIL_REGEX = r"[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,4}"
PHONE_REGEX = r"\(?(\d{3})?\)?[\s\.-]{0,2}?(\d{3})[\s\.-]{0,2}(\d{4})"

re.search("spain", txt)
# Out:
# <_sre.SRE_Match object; span=(8, 13), match='spain'>

# %%
mob_num_regex = r'''\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}
                    |\(\d{3}\)[-\.\s]*\d{3}[-\.\s]??\d{4}
                    |\d{3}[-\.\s]??\d{4}
                    |\(\d{3}[)-\.\s].\d{3}.\d{4}'''

# %%
phone = re.findall(re.compile(mob_num_regex), '+1 (205) 200-8202')
phone
# Out:
# ['(205) 200-8202']

# %%
re.findall(re.compile(r'\(\d{3}[)-\.\s].\d{3}.\d{4}'), '+1 (205) 200-8202')
# Out:
# ['(205) 200-8202']

# %%
test_address = """
    94 Central Avenue Jersey City NJ 07306
    """

# %%
addresses = pyap.parse(test_address, country='US')

# %%
addresses
# Out:
# [94 Central Avenue Jersey City NJ 07306]

# %%
import spacy

# %%
sp_lg = spacy.load('en_core_web_lg')
{(ent.text.strip(), ent.label_) for ent in sp_lg(document).ents}
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-106-b4b88fd4ddb4> in <module>
# ----> 1 sp_lg = spacy.load('en_core_web_lg')
#       2 {(ent.text.strip(), ent.label_) for ent in sp_lg(document).ents}
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/anaconda3/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     137     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     138         return load_model_from_path(name, **overrides)
# --> 139     raise IOError(Errors.E050.format(name=name))
#     140
#     141
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
import sys
sys.version
# Out:
# '3.6.8 |Anaconda custom (64-bit)| (default, Dec 29 2018, 19:04:46) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
np = spacy.load('en_core_web_lg')

# %%
docs = np("""Bharat Sri Harsha Karpurapu authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices""")

# %%
print((X.text, X.label_) for X in docs.ents])
# Out:
# (Bharat Sri Harsha Karpurapu, Google, $5.1 billion, Wednesday)

# %%
# Importing libraries
import sys
import os
import re
import pyap
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convertPDFToText(path):
    """
    This function converts pdf to text

    path: path of the file to be converted
    """
    fp = open(path, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    return data

# %%
f = convertPDFToText("Resume_Harsha_Updated.pdf")
f1 = re.sub("\n", "", f)

# %%
doc1 = np("BHARAT Sri Harsha Karpurapu")

# %%
f1
# Out:
# '94, Central Ave, APT 1, Jersey City, NJ, 07306 BHARAT SRI HARSHA KARPURAPU +1 (205) 200-8202 kbsriharsha@gmail.com  https://github.com/kbsriharsha/DataScience (Aug 2015 – April 2017) (June 2018 – Current) https://www.linkedin.com/in/kbsriharsha/   Seasoned data scientist with nearly 4 plus years of domain experience through professional work and research,  and with demonstrated abilities in delivering actionable insights using advanced data-driven methods  Proven credentials in developing and delivering complex business solutions with strong emphasis on machine  learning, deep learning, big data analytics, natural language processing, statistics, and high-performance computing  Has expert level of knowledge in various data science technology platforms and highly skilled in orchestrating data from various sources (on premise, cloud, and different vendors) and developing data driven predictive applications   PROFESSIONAL EXPERIENCE   New York Life Insurance – New York City, NY  Senior Associate, Data Science  - Functioning as one of the data experts and tech liaisons of the team assigned to curate, design, and develop the model ready data sets and introduce the latest cutting edge algorithms and platforms for increased computation speed and accuracy  - Successfully designed and implemented a process for cleaning the unstructured beneficiary records using Natural Language Processing techniques and saved 2 million$ vendor cost  - Creating model ready dataset (MRD) for agent compliance model; which is aimed to classify the non-compliant vs compliant agents as per the NYL rules  Regions Bank – Birmingham, AL  Data Scientist (June 2017 – May 2018) Data Scientist Intern (Jan 2016 – May 2017)  - Part of the new data science team (4 members) created under the CDO (Chief Data Officer) for developing predictive analytics and augmented intelligence applications to help the bank in process improvement and for finding new opportunities  - As a team, assigned to create and architect an enterprise big data environment with Hadoop echo system and IBM Power Minskey (Nvidia P100 GPU’s) to facilitate data science team and quant squad in the bank  - Successfully  developed  applications  like  Intelligent  Web  Scrapper  for  getting  information  on  potential  customers from the web, Regions Business Universe which facilitates various departments of the bank to take quick customer decisions and contributed in delivering quick process for CIP (Customer Identification Program) which decrease the process time from 20 min to 3 min  - Acted as lead role for determining the POCO (Probability of Charge-off) for an overdraft account, and replaced the  old model with the new model with 4% increase in accuracy.   EDUCATION   University of Alabama at Birmingham (Master’s Degree)  Electrical and Computer Engineering Dept. (Data Science Concentration) (G.P.A: 4.0)  Research Fields: Machine Learning, Deep Learning, Big Data Analytics, Natural Language Processing, and High Performance Computing  Thesis Title: Framework for Social Network Sentiment Analysis Using Big Data Analytics  - Developed a generalized framework for performing social network sentiment analysis on any kind of domain such as automobile, banking and telecom  - Studied numerous research papers on natural language processing, big data analytics and machine learning   Publication: Big Data and Visual Analytics, Springer 2017, Chapter 12, Page: 203-218 * Case Study: Automobile * Popular: BMW * Highest Sentiment: Mercedes (0.87) * Lowest Sentiment: Buick(0.49) (Jan 2016 –May 2018) \x0c'

# %%
print([(X.text, X.label_) for X in doc1.ents])
# Out:
# [('BHARAT', 'ORG'), ('Harsha Karpurapu', 'PERSON')]

# %%
from pyresparser import ResumeParser

# %%
ResumeParser('Resume_Harsha_Updated.pdf').get_extracted_data()
# Out:
# {'name': 'Central Ave',
#  'email': 'kbsriharsha@gmail.com',
#  'mobile_number': None,
#  'skills': ['Compliance',
#   'Improvement',
#   'Machine learning',
#   'Design',
#   'Telecom',
#   'Engineering',
#   'Process improvement',
#   'System',
#   'Statistics',
#   'Algorithms',
#   'Visual',
#   'Analysis',
#   'Ibm',
#   'Process',
#   'Hadoop',
#   'Banking',
#   'Vendors',
#   'Electrical',
#   'Analytics',
#   'Research',
#   'Big data',
#   'Cloud',
#   'Predictive analytics'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': ['New York Life Insurance – New York City, NY',
#   'Senior Associate, Data Science',
#   '- Functioning as one of the data experts and tech liaisons of the team assigned to curate, design, and develop the',
#   'model ready data sets and introduce the latest cutting edge algorithms and platforms for increased computation',
#   'speed and accuracy',
#   '- Successfully designed and implemented a process for cleaning the unstructured beneficiary records',
#   'using Natural Language Processing techniques and saved 2 million$ vendor cost',
#   '- Creating model ready dataset (MRD) for agent compliance model; which is aimed to classify the non-compliant',
#   'vs compliant agents as per the NYL rules',
#   'Regions Bank – Birmingham, AL',
#   'Data Scientist (June 2017 – May 2018)',
#   'Data Scientist Intern (Jan 2016 – May 2017)',
#   '- Part of the new data science team (4 members) created under the CDO (Chief Data Officer) for developing',
#   'predictive analytics and augmented intelligence applications to help the bank in process improvement and for finding',
#   'new opportunities',
#   '- As a team, assigned to create and architect an enterprise big data environment with Hadoop echo system and IBM',
#   'Power Minskey (Nvidia P100 GPU’s) to facilitate data science team and quant squad in the bank',
#   '- Successfully  developed  applications  like  Intelligent  Web  Scrapper  for  getting  information  on  potential  customers',
#   'from the web, Regions Business Universe which facilitates various departments of the bank to take quick customer',
#   'decisions and contributed in delivering quick process for CIP (Customer Identification Program) which decrease the',
#   'process time from 20 min to 3 min',
#   '- Acted as lead role for determining the POCO (Probability of Charge-off) for an overdraft account, and replaced the',
#   'old model with the new model with 4% increase in accuracy.'],
#  'company_names': None,
#  'no_of_pages': 1,
#  'total_experience': 2.25}

# %%
import nltk
grammar = r'{<NN.*><NN.*><NN.*>*}'
chunkParser = nltk.RegexpParser(grammar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f8ab4da6f031> in <module>
#       1 import nltk
#       2 grammar = r'{<NN.*><NN.*><NN.*>*}'
# ----> 3 chunkParser = nltk.RegexpParser(grammar)
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/chunk/regexp.py in __init__(self, grammar, root_label, loop, trace)
#    1212
#    1213         if isinstance(grammar, string_types):
# -> 1214             self._read_grammar(grammar, root_label, trace)
#    1215         else:
#    1216             # Make sur the grammar looks like it has the right type:
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/chunk/regexp.py in _read_grammar(self, grammar, root_label, trace)
#    1255
#    1256         # Record the final stage
# -> 1257         self._add_stage(rules, lhs, root_label, trace)
#    1258
#    1259     def _add_stage(self, rules, lhs, root_label, trace):
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/chunk/regexp.py in _add_stage(self, rules, lhs, root_label, trace)
#    1263         if rules != []:
#    1264             if not lhs:
# -> 1265                 raise ValueError('Expected stage marker (eg NP:)')
#    1266             parser = RegexpChunkParser(
#    1267                 rules, chunk_label=lhs, root_label=root_label, trace=trace
#
# ValueError: Expected stage marker (eg NP:)

# %%
nltk.sent_tokenize(f)[2]
[nltk.pos_tag(sent) for sent in nltk.sent_tokenize(f)]
# Out:
# [[('9', 'CD'),
#   ('4', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('A', 'DT'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('A', 'NNP'),
#   ('P', 'NNP'),
#   ('T', 'NNP'),
#   (' ', 'NNP'),
#   ('1', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('J', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('e', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'NN'),
#   ('y', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('J', 'NNP'),
#   (',', ','),
#   (' ', 'VBD'),
#   ('0', 'CD'),
#   ('7', 'CD'),
#   ('3', 'CD'),
#   ('0', 'CD'),
#   ('6', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('B', 'NNP'),
#   ('H', 'NNP'),
#   ('A', 'NNP'),
#   ('R', 'NNP'),
#   ('A', 'NNP'),
#   ('T', 'NNP'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('R', 'NNP'),
#   ('I', 'PRP'),
#   (' ', 'VBP'),
#   ('H', 'PRP'),
#   ('A', 'DT'),
#   ('R', 'NNP'),
#   ('S', 'NNP'),
#   ('H', 'NNP'),
#   ('A', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('K', 'NNP'),
#   ('A', 'NNP'),
#   ('R', 'NNP'),
#   ('P', 'NNP'),
#   ('U', 'NNP'),
#   ('R', 'NNP'),
#   ('A', 'NNP'),
#   ('P', 'NNP'),
#   ('U', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('+', 'VBD'),
#   ('1', 'CD'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('5', 'CD'),
#   (')', ')'),
#   (' ', 'VBD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('0', 'CD'),
#   ('-', ':'),
#   ('8', 'CD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('2', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('@', 'JJ'),
#   ('g', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('l', 'NN'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('t', 'NN'),
#   ('p', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   ('/', 'JJ'),
#   ('/', 'NNP'),
#   ('g', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   ('u', 'JJ'),
#   ('b', 'NN'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('/', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('/', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   ('S', 'NNP'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('J', 'NNP'),
#   ('u', 'RB'),
#   ('n', 'RB'),
#   ('e', 'JJ'),
#   (' ', 'VBP'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('t', 'NN'),
#   ('p', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   ('/', 'JJ'),
#   ('/', 'NNP'),
#   ('w', 'NN'),
#   ('w', 'NN'),
#   ('w', 'NN'),
#   ('.', '.'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('k', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('.', '.'),
#   ('c', 'VB'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('/', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('/', 'NNP'),
#   ('k', 'NN'),
#   ('b', 'NN'),
#   ('s', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('h', 'VBP'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('/', 'JJ'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('s', 'NN'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'RB'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   (' ', 'VBD'),
#   ('4', 'CD'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('y', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('n', 'NN'),
#   (' ', 'NNP'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('h', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('g', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('f', 'NN'),
#   ('e', 'NN'),
#   ('s', 'VBD'),
#   ('s', 'JJ'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'IN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('m', 'NN'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   ('i', 'JJ'),
#   ('t', 'VBP'),
#   ('i', 'JJ'),
#   ('e', 'VBP'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'IN'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('t', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('d', 'NN'),
#   ('v', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   ('-', ':'),
#   ('d', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('t', 'NN'),
#   ('h', 'NN'),
#   ('o', 'JJ'),
#   ('d', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('c', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'IN'),
#   ('p', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('u', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'NN'),
#   ('l', 'NN'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('w', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('e', 'VBZ'),
#   ('m', 'FW'),
#   ('p', 'NN'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('m', 'NN'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('i', 'JJ'),
#   ('n', 'VBP'),
#   ('e', 'JJ'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('e', 'FW'),
#   ('e', 'FW'),
#   ('p', 'FW'),
#   (' ', 'FW'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('n', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('s', 'VBZ'),
#   ('t', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'SYM'),
#   ('-', ':'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   ('p', 'NN'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('H', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('e', 'NN'),
#   ('x', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('k', 'NN'),
#   ('n', 'NNP'),
#   ('o', 'VBZ'),
#   ('w', 'JJ'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NNP'),
#   ('v', 'FW'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('s', 'NN'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('n', 'JJ'),
#   ('o', 'NN'),
#   ('l', 'NN'),
#   ('o', 'NN'),
#   ('g', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'NN'),
#   ('s', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('k', 'NN'),
#   ('i', 'JJ'),
#   ('l', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   (' ', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('f', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('v', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('o', 'JJ'),
#   ('n', 'RB'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('e', 'IN'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('c', 'VBZ'),
#   ('l', 'JJ'),
#   ('o', 'JJ'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('f', 'VBP'),
#   ('f', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'IN'),
#   ('p', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('p', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('R', 'NNP'),
#   ('O', 'NNP'),
#   ('F', 'NNP'),
#   ('E', 'NNP'),
#   ('S', 'NNP'),
#   ('S', 'NNP'),
#   ('I', 'PRP'),
#   ('O', 'NNP'),
#   ('N', 'NNP'),
#   ('A', 'NNP'),
#   ('L', 'NNP'),
#   (' ', 'NNP'),
#   ('E', 'NNP'),
#   ('X', 'NNP'),
#   ('P', 'NNP'),
#   ('E', 'NNP'),
#   ('R', 'NNP'),
#   ('I', 'PRP'),
#   ('E', 'VBP'),
#   ('N', 'NNP'),
#   ('C', 'NNP'),
#   ('E', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   (' ', 'NNP'),
#   ('Y', 'NNP'),
#   ('o', 'MD'),
#   ('r', 'VB'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('i', 'NN'),
#   ('f', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NN'),
#   ('I', 'PRP'),
#   ('n', 'VBP'),
#   ('s', 'JJ'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('–', 'NNP'),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   (' ', 'NNP'),
#   ('Y', 'NNP'),
#   ('o', 'MD'),
#   ('r', 'VB'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'NN'),
#   ('y', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('Y', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ...],
#  [('E', 'NNP'),
#   ('D', 'NNP'),
#   ('U', 'NNP'),
#   ('C', 'NNP'),
#   ('A', 'NNP'),
#   ('T', 'NNP'),
#   ('I', 'PRP'),
#   ('O', 'NNP'),
#   ('N', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('U', 'NNP'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('v', 'VBP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'IN'),
#   ('A', 'NNP'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('b', 'NN'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('r', 'VBP'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   ('h', 'NN'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   (' ', 'NN'),
#   ('(', '('),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('g', 'NN'),
#   ('r', 'NN'),
#   ('e', 'FW'),
#   ('e', 'NN'),
#   (')', ')'),
#   (' ', 'VBZ'),
#   ('\n', 'JJ'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('E', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('c', 'NN'),
#   ('t', 'IN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('m', 'VB'),
#   ('p', 'JJ'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('E', 'NNP'),
#   ('n', 'IN'),
#   ('g', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('p', 'NN'),
#   ('t', 'NN'),
#   ('.', '.')],
#  [('(', '('),
#   ('D', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('S', 'NNP'),
#   ('c', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('n', 'VB'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('n', 'NNS'),
#   ('t', 'VBP'),
#   ('r', 'VB'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'NN'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('(', '('),
#   ('G', 'NNP'),
#   ('.', '.'),
#   ('P', 'NNP'),
#   ('.', '.'),
#   ('A', 'DT'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('4', 'CD'),
#   ('.', '.'),
#   ('0', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('R', 'NNP'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('F', 'NNP'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('l', 'NN'),
#   ('d', 'NN'),
#   ('s', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   ('i', 'JJ'),
#   ('n', 'VBP'),
#   ('e', 'JJ'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('e', 'NN'),
#   ('p', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'VB'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('H', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('o', 'MD'),
#   ('m', 'VB'),
#   ('p', 'JJ'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('T', 'NNP'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'IN'),
#   ('T', 'NNP'),
#   ('i', 'NN'),
#   ('t', 'VBP'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('F', 'NNP'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('o', 'IN'),
#   ('c', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('N', 'NNP'),
#   ('e', 'NN'),
#   ('t', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'VBD'),
#   ('A', 'NNP'),
#   ('n', 'FW'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('U', 'NNP'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('-', ':'),
#   (' ', 'NN'),
#   ('D', 'NNP'),
#   ('e', 'NN'),
#   ('v', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('o', 'NN'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   (' ', 'JJ'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('e', 'NN'),
#   ('r', 'VBZ'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('z', 'VBP'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'VBZ'),
#   ('r', 'VB'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('f', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('m', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('o', 'IN'),
#   ('c', 'NN'),
#   ('i', 'VBP'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'CC'),
#   ('e', 'JJ'),
#   ('t', 'NN'),
#   ('w', 'NN'),
#   ('o', 'NN'),
#   ('r', 'NN'),
#   ('k', 'NN'),
#   (' ', 'NNP'),
#   ('s', 'NN'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'VBD'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   (' ', 'JJ'),
#   ('o', 'NN'),
#   ('n', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('y', 'NN'),
#   (' ', 'NNP'),
#   ('k', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('f', 'JJ'),
#   (' ', 'NNP'),
#   ('d', 'NN'),
#   ('o', 'NN'),
#   ('m', 'VBD'),
#   ('a', 'DT'),
#   ('i', 'JJ'),
#   ('n', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('s', 'VBD'),
#   ('u', 'JJ'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'VBZ'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('o', 'NN'),
#   ('m', 'NN'),
#   ('o', 'IN'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('k', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('l', 'NN'),
#   ('e', 'NN'),
#   ('c', 'VBP'),
#   ('o', 'JJ'),
#   ('m', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('-', ':'),
#   (' ', 'NN'),
#   ('S', 'NNP'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   ('i', 'NN'),
#   ('e', 'VBP'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('n', 'CC'),
#   ('u', 'JJ'),
#   ('m', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('o', 'NN'),
#   ('u', 'JJ'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('r', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('h', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'VBZ'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('o', 'VBZ'),
#   ('n', 'JJ'),
#   (' ', 'NNP'),
#   ('n', 'FW'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('r', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'VBZ'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('g', 'NN'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('o', 'IN'),
#   ('c', 'JJ'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('s', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('d', 'VBZ'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (' ', 'VBP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('m', 'VBZ'),
#   ('a', 'DT'),
#   ('c', 'JJ'),
#   ('h', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('l', 'NN'),
#   ('e', 'VBZ'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   ('n', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   (' ', 'NNP'),
#   ('\n', 'NNP'),
#   ('P', 'NNP'),
#   ('u', 'NN'),
#   ('b', 'NN'),
#   ('l', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('o', 'VBP'),
#   ('n', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   (' ', 'NNP'),
#   ('D', 'NNP'),
#   ('a', 'DT'),
#   ('t', 'NN'),
#   ('a', 'DT'),
#   (' ', 'NN'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   ('d', 'NN'),
#   (' ', 'NNP'),
#   ('V', 'NNP'),
#   ('i', 'NN'),
#   ('s', 'VBP'),
#   ('u', 'IN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   (' ', 'VBZ'),
#   ('A', 'NNP'),
#   ('n', 'NN'),
#   ('a', 'DT'),
#   ('l', 'NN'),
#   ('y', 'NN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('s', 'NN'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('p', 'IN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('n', 'VBP'),
#   ('g', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'VBD'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('7', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('h', 'VBD'),
#   ('a', 'DT'),
#   ('p', 'NN'),
#   ('t', 'NN'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   (' ', 'VBD'),
#   ('1', 'CD'),
#   ('2', 'CD'),
#   (',', ','),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('a', 'DT'),
#   ('g', 'JJ'),
#   ('e', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('3', 'CD'),
#   ('-', ':'),
#   ('2', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (' ', 'NN'),
#   ('\n', 'NNP'),
#   ('\n', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('C', 'NNP'),
#   ('a', 'DT'),
#   ('s', 'JJ'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('t', 'NN'),
#   ('u', 'JJ'),
#   ('d', 'NN'),
#   ('y', 'NN'),
#   (':', ':'),
#   (' ', 'VB'),
#   ('A', 'DT'),
#   ('u', 'JJ'),
#   ('t', 'NN'),
#   ('o', 'NN'),
#   ('m', 'NN'),
#   ('o', 'IN'),
#   ('b', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   ('e', 'NN'),
#   (' ', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('P', 'NNP'),
#   ('o', 'MD'),
#   ('p', 'VB'),
#   ('u', 'JJ'),
#   ('l', 'NN'),
#   ('a', 'DT'),
#   ('r', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('M', 'NNP'),
#   ('W', 'NNP'),
#   (' ', 'NNP'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('H', 'NNP'),
#   ('i', 'NN'),
#   ('g', 'VBP'),
#   ('h', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (':', ':'),
#   (' ', 'JJ'),
#   ('M', 'NNP'),
#   ('e', 'NN'),
#   ('r', 'NN'),
#   ('c', 'NN'),
#   ('e', 'NN'),
#   ('d', 'NN'),
#   ('e', 'NN'),
#   ('s', 'NN'),
#   (' ', 'NNP'),
#   ('(', '('),
#   ('0', 'CD'),
#   ('.', '.'),
#   ('8', 'CD'),
#   ('7', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('*', 'NNP'),
#   (' ', 'NNP'),
#   ('L', 'NNP'),
#   ('o', 'MD'),
#   ('w', 'VB'),
#   ('e', 'NN'),
#   ('s', 'JJ'),
#   ('t', 'NN'),
#   (' ', 'NNP'),
#   ('S', 'NNP'),
#   ('e', 'NN'),
#   ('n', 'IN'),
#   ('t', 'NN'),
#   ('i', 'NN'),
#   ('m', 'VBP'),
#   ('e', 'NN'),
#   ('n', 'JJ'),
#   ('t', 'NN'),
#   (':', ':'),
#   (' ', 'NN'),
#   ('B', 'NNP'),
#   ('u', 'NN'),
#   ('i', 'NN'),
#   ('c', 'VBP'),
#   ('k', 'NN'),
#   ('(', '('),
#   ('0', 'CD'),
#   ('.', '.'),
#   ('4', 'CD'),
#   ('9', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('J', 'NNP'),
#   ('a', 'DT'),
#   ('n', 'JJ'),
#   (' ', 'NN'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('6', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   ('M', 'NNP'),
#   ('a', 'DT'),
#   ('y', 'NN'),
#   (' ', 'VBZ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('8', 'CD'),
#   (')', ')'),
#   (' ', 'NN'),
#   ('\n', 'JJ'),
#   ('\n', 'NNP'),
#   ('(', '('),
#   ('A', 'NNP'),
#   ('u', 'RB'),
#   ('g', 'VBZ'),
#   (' ', 'JJ'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('5', 'CD'),
#   (' ', 'NN'),
#   ('–', 'NNP'),
#   (' ', 'VBZ'),
#   ('A', 'NNP'),
#   ('p', 'NN'),
#   ('r', 'NN'),
#   ('i', 'NN'),
#   ('l', 'VBP'),
#   (' ', '$'),
#   ('2', 'CD'),
#   ('0', 'CD'),
#   ('1', 'CD'),
#   ('7', 'CD'),
#   (')', ')')]]

# %%
def preprocess(document):
        '''
        Information Extraction: Preprocess a document with the necessary POS tagging.
        Returns three lists, one with tokens, one with POS tagged lines, one with POS tagged sentences.
        Modules required: nltk
        '''

        # Newlines are one element of structure in the data
        # Helps limit the context and breaks up the data as is intended in resumes - i.e., into points
        lines = [el.strip() for el in document.split("\n") if len(el) > 0]  # Splitting on the basis of newlines 
        lines = [nltk.word_tokenize(el) for el in lines]    # Tokenize the individual lines
        lines = [nltk.pos_tag(el) for el in lines]  # Tag them
        # Below approach is slightly different because it splits sentences not just on the basis of newlines, but also full stops 
        # - (barring abbreviations etc.)
        # But it fails miserably at predicting names, so currently using it only for tokenization of the whole document
        sentences = nltk.sent_tokenize(document)    # Split/Tokenize into sentences (List of strings)
        sentences = [nltk.word_tokenize(sent) for sent in sentences]    # Split/Tokenize sentences into words (List of lists of strings)
        tokens = sentences
        sentences = [nltk.pos_tag(sent) for sent in sentences]    # Tag the tokens - list of lists of tuples - each tuple is (<word>, <tag>)
        # Next 4 lines convert tokens from a list of list of strings to a list of strings; basically stitches them together
        dummy = []
        for el in tokens:
            dummy += el
        tokens = dummy
        # tokens - words extracted from the doc, lines - split only based on newlines (may have more than one sentence)
        # sentences - split on the basis of rules of grammar
        return tokens, lines, sentences

# %%
preprocess(f)[2]
# Out:
# [[('94', 'CD'),
#   (',', ','),
#   ('Central', 'NNP'),
#   ('Ave', 'NNP'),
#   (',', ','),
#   ('APT', 'NNP'),
#   ('1', 'CD'),
#   (',', ','),
#   ('Jersey', 'NNP'),
#   ('City', 'NNP'),
#   (',', ','),
#   ('NJ', 'NNP'),
#   (',', ','),
#   ('07306', 'CD'),
#   ('BHARAT', 'NNP'),
#   ('SRI', 'NNP'),
#   ('HARSHA', 'NNP'),
#   ('KARPURAPU', 'NNP'),
#   ('+1', 'NNP'),
#   ('(', '('),
#   ('205', 'CD'),
#   (')', ')'),
#   ('200-8202', 'CD'),
#   ('kbsriharsha', 'NN'),
#   ('@', 'NNP'),
#   ('gmail.com', 'NN'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//github.com/kbsriharsha/DataScience', 'NN'),
#   ('(', '('),
#   ('June', 'NNP'),
#   ('2018', 'CD'),
#   ('–', 'NNP'),
#   ('Current', 'NNP'),
#   (')', ')'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//www.linkedin.com/in/kbsriharsha/', 'NN'),
#   ('Seasoned', 'VBD'),
#   ('data', 'NNS'),
#   ('scientist', 'NN'),
#   ('with', 'IN'),
#   ('nearly', 'RB'),
#   ('4', 'CD'),
#   ('plus', 'JJ'),
#   ('years', 'NNS'),
#   ('of', 'IN'),
#   ('domain', 'NN'),
#   ('experience', 'NN'),
#   ('through', 'IN'),
#   ('professional', 'JJ'),
#   ('work', 'NN'),
#   ('and', 'CC'),
#   ('research', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('with', 'IN'),
#   ('demonstrated', 'JJ'),
#   ('abilities', 'NNS'),
#   ('in', 'IN'),
#   ('delivering', 'VBG'),
#   ('actionable', 'JJ'),
#   ('insights', 'NNS'),
#   ('using', 'VBG'),
#   ('advanced', 'JJ'),
#   ('data-driven', 'JJ'),
#   ('methods', 'NNS'),
#   ('Proven', 'NNP'),
#   ('credentials', 'NNS'),
#   ('in', 'IN'),
#   ('developing', 'VBG'),
#   ('and', 'CC'),
#   ('delivering', 'VBG'),
#   ('complex', 'JJ'),
#   ('business', 'NN'),
#   ('solutions', 'NNS'),
#   ('with', 'IN'),
#   ('strong', 'JJ'),
#   ('emphasis', 'NN'),
#   ('on', 'IN'),
#   ('machine', 'NN'),
#   ('learning', 'NN'),
#   (',', ','),
#   ('deep', 'JJ'),
#   ('learning', 'NN'),
#   (',', ','),
#   ('big', 'JJ'),
#   ('data', 'NN'),
#   ('analytics', 'NNS'),
#   (',', ','),
#   ('natural', 'JJ'),
#   ('language', 'NN'),
#   ('processing', 'NN'),
#   (',', ','),
#   ('statistics', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('high-performance', 'NN'),
#   ('computing', 'NN'),
#   ('Has', 'NNP'),
#   ('expert', 'NN'),
#   ('level', 'NN'),
#   ('of', 'IN'),
#   ('knowledge', 'NN'),
#   ('in', 'IN'),
#   ('various', 'JJ'),
#   ('data', 'NNS'),
#   ('science', 'NN'),
#   ('technology', 'NN'),
#   ('platforms', 'NNS'),
#   ('and', 'CC'),
#   ('highly', 'RB'),
#   ('skilled', 'VBN'),
#   ('in', 'IN'),
#   ('orchestrating', 'VBG'),
#   ('data', 'NNS'),
#   ('from', 'IN'),
#   ('various', 'JJ'),
#   ('sources', 'NNS'),
#   ('(', '('),
#   ('on', 'IN'),
#   ('premise', 'NN'),
#   (',', ','),
#   ('cloud', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('different', 'JJ'),
#   ('vendors', 'NNS'),
#   (')', ')'),
#   ('and', 'CC'),
#   ('developing', 'VBG'),
#   ('data', 'NNS'),
#   ('driven', 'RB'),
#   ('predictive', 'JJ'),
#   ('applications', 'NNS'),
#   ('PROFESSIONAL', 'NNP'),
#   ('EXPERIENCE', 'NNP'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Life', 'NNP'),
#   ('Insurance', 'NNP'),
#   ('–', 'NNP'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('City', 'NNP'),
#   (',', ','),
#   ('NY', 'NNP'),
#   ('Senior', 'NNP'),
#   ('Associate', 'NNP'),
#   (',', ','),
#   ('Data', 'NNP'),
#   ('Science', 'NNP'),
#   ('-', ':'),
#   ('Functioning', 'VBG'),
#   ('as', 'IN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('data', 'NN'),
#   ('experts', 'NNS'),
#   ('and', 'CC'),
#   ('tech', 'JJ'),
#   ('liaisons', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('team', 'NN'),
#   ('assigned', 'VBD'),
#   ('to', 'TO'),
#   ('curate', 'VB'),
#   (',', ','),
#   ('design', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('develop', 'VB'),
#   ('the', 'DT'),
#   ('model', 'NN'),
#   ('ready', 'JJ'),
#   ('data', 'NNS'),
#   ('sets', 'NNS'),
#   ('and', 'CC'),
#   ('introduce', 'VB'),
#   ('the', 'DT'),
#   ('latest', 'JJS'),
#   ('cutting', 'NN'),
#   ('edge', 'NN'),
#   ('algorithms', 'NN'),
#   ('and', 'CC'),
#   ('platforms', 'NNS'),
#   ('for', 'IN'),
#   ('increased', 'JJ'),
#   ('computation', 'NN'),
#   ('speed', 'NN'),
#   ('and', 'CC'),
#   ('accuracy', 'NN'),
#   ('-', ':'),
#   ('Successfully', 'RB'),
#   ('designed', 'VBN'),
#   ('and', 'CC'),
#   ('implemented', 'VBN'),
#   ('a', 'DT'),
#   ('process', 'NN'),
#   ('for', 'IN'),
#   ('cleaning', 'VBG'),
#   ('the', 'DT'),
#   ('unstructured', 'JJ'),
#   ('beneficiary', 'NN'),
#   ('records', 'NNS'),
#   ('using', 'VBG'),
#   ('Natural', 'NNP'),
#   ('Language', 'NNP'),
#   ('Processing', 'NNP'),
#   ('techniques', 'NNS'),
#   ('and', 'CC'),
#   ('saved', 'VBD'),
#   ('2', 'CD'),
#   ('million', 'CD'),
#   ('$', '$'),
#   ('vendor', 'NN'),
#   ('cost', 'NN'),
#   ('-', ':'),
#   ('Creating', 'VBG'),
#   ('model', 'NN'),
#   ('ready', 'JJ'),
#   ('dataset', 'NN'),
#   ('(', '('),
#   ('MRD', 'NNP'),
#   (')', ')'),
#   ('for', 'IN'),
#   ('agent', 'NN'),
#   ('compliance', 'NN'),
#   ('model', 'NN'),
#   (';', ':'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('aimed', 'VBN'),
#   ('to', 'TO'),
#   ('classify', 'VB'),
#   ('the', 'DT'),
#   ('non-compliant', 'JJ'),
#   ('vs', 'NN'),
#   ('compliant', 'NN'),
#   ('agents', 'NNS'),
#   ('as', 'IN'),
#   ('per', 'IN'),
#   ('the', 'DT'),
#   ('NYL', 'NNP'),
#   ('rules', 'NNS'),
#   ('Regions', 'NNP'),
#   ('Bank', 'NNP'),
#   ('–', 'NNP'),
#   ('Birmingham', 'NNP'),
#   (',', ','),
#   ('AL', 'NNP'),
#   ('Data', 'NNP'),
#   ('Scientist', 'NNP'),
#   ('(', '('),
#   ('June', 'NNP'),
#   ('2017', 'CD'),
#   ('–', 'NN'),
#   ('May', 'NNP'),
#   ('2018', 'CD'),
#   (')', ')'),
#   ('Data', 'NNP'),
#   ('Scientist', 'NNP'),
#   ('Intern', 'NNP'),
#   ('(', '('),
#   ('Jan', 'NNP'),
#   ('2016', 'CD'),
#   ('–', 'NN'),
#   ('May', 'NNP'),
#   ('2017', 'CD'),
#   (')', ')'),
#   ('-', ':'),
#   ('Part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('data', 'NNS'),
#   ('science', 'NN'),
#   ('team', 'NN'),
#   ('(', '('),
#   ('4', 'CD'),
#   ('members', 'NNS'),
#   (')', ')'),
#   ('created', 'VBD'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('CDO', 'NNP'),
#   ('(', '('),
#   ('Chief', 'NNP'),
#   ('Data', 'NNP'),
#   ('Officer', 'NNP'),
#   (')', ')'),
#   ('for', 'IN'),
#   ('developing', 'VBG'),
#   ('predictive', 'JJ'),
#   ('analytics', 'NNS'),
#   ('and', 'CC'),
#   ('augmented', 'JJ'),
#   ('intelligence', 'NN'),
#   ('applications', 'NNS'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('in', 'IN'),
#   ('process', 'NN'),
#   ('improvement', 'NN'),
#   ('and', 'CC'),
#   ('for', 'IN'),
#   ('finding', 'VBG'),
#   ('new', 'JJ'),
#   ('opportunities', 'NNS'),
#   ('-', ':'),
#   ('As', 'IN'),
#   ('a', 'DT'),
#   ('team', 'NN'),
#   (',', ','),
#   ('assigned', 'VBN'),
#   ('to', 'TO'),
#   ('create', 'VB'),
#   ('and', 'CC'),
#   ('architect', 'VB'),
#   ('an', 'DT'),
#   ('enterprise', 'NN'),
#   ('big', 'JJ'),
#   ('data', 'NNS'),
#   ('environment', 'NN'),
#   ('with', 'IN'),
#   ('Hadoop', 'NNP'),
#   ('echo', 'NN'),
#   ('system', 'NN'),
#   ('and', 'CC'),
#   ('IBM', 'NNP'),
#   ('Power', 'NNP'),
#   ('Minskey', 'NNP'),
#   ('(', '('),
#   ('Nvidia', 'NNP'),
#   ('P100', 'NNP'),
#   ('GPU', 'NNP'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   (')', ')'),
#   ('to', 'TO'),
#   ('facilitate', 'VB'),
#   ('data', 'NNS'),
#   ('science', 'NN'),
#   ('team', 'NN'),
#   ('and', 'CC'),
#   ('quant', 'JJ'),
#   ('squad', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('-', ':'),
#   ('Successfully', 'NNP'),
#   ('developed', 'VBD'),
#   ('applications', 'NNS'),
#   ('like', 'IN'),
#   ('Intelligent', 'NNP'),
#   ('Web', 'NNP'),
#   ('Scrapper', 'NNP'),
#   ('for', 'IN'),
#   ('getting', 'VBG'),
#   ('information', 'NN'),
#   ('on', 'IN'),
#   ('potential', 'JJ'),
#   ('customers', 'NNS'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('web', 'NN'),
#   (',', ','),
#   ('Regions', 'NNP'),
#   ('Business', 'NNP'),
#   ('Universe', 'NNP'),
#   ('which', 'WDT'),
#   ('facilitates', 'VBZ'),
#   ('various', 'JJ'),
#   ('departments', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('quick', 'JJ'),
#   ('customer', 'NN'),
#   ('decisions', 'NNS'),
#   ('and', 'CC'),
#   ('contributed', 'VBN'),
#   ('in', 'IN'),
#   ('delivering', 'VBG'),
#   ('quick', 'JJ'),
#   ('process', 'NN'),
#   ('for', 'IN'),
#   ('CIP', 'NNP'),
#   ('(', '('),
#   ('Customer', 'NNP'),
#   ('Identification', 'NNP'),
#   ('Program', 'NNP'),
#   (')', ')'),
#   ('which', 'WDT'),
#   ('decrease', 'VBP'),
#   ('the', 'DT'),
#   ('process', 'NN'),
#   ('time', 'NN'),
#   ('from', 'IN'),
#   ('20', 'CD'),
#   ('min', 'NNS'),
#   ('to', 'TO'),
#   ('3', 'CD'),
#   ('min', 'NNS'),
#   ('-', ':'),
#   ('Acted', 'VBN'),
#   ('as', 'IN'),
#   ('lead', 'JJ'),
#   ('role', 'NN'),
#   ('for', 'IN'),
#   ('determining', 'VBG'),
#   ('the', 'DT'),
#   ('POCO', 'NNP'),
#   ('(', '('),
#   ('Probability', 'NNP'),
#   ('of', 'IN'),
#   ('Charge-off', 'NNP'),
#   (')', ')'),
#   ('for', 'IN'),
#   ('an', 'DT'),
#   ('overdraft', 'NN'),
#   ('account', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('replaced', 'VBD'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('model', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('model', 'NN'),
#   ('with', 'IN'),
#   ('4', 'CD'),
#   ('%', 'NN'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('accuracy', 'NN'),
#   ('.', '.')],
#  [('EDUCATION', 'NNP'),
#   ('University', 'NNP'),
#   ('of', 'IN'),
#   ('Alabama', 'NNP'),
#   ('at', 'IN'),
#   ('Birmingham', 'NNP'),
#   ('(', '('),
#   ('Master', 'NNP'),
#   ('’', 'NNP'),
#   ('s', 'VBD'),
#   ('Degree', 'NNP'),
#   (')', ')'),
#   ('Electrical', 'NNP'),
#   ('and', 'CC'),
#   ('Computer', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('Dept', 'NNP'),
#   ('.', '.')],
#  [('(', '('),
#   ('Data', 'NNP'),
#   ('Science', 'NNP'),
#   ('Concentration', 'NNP'),
#   (')', ')'),
#   ('(', '('),
#   ('G.P.A', 'NNP'),
#   (':', ':'),
#   ('4.0', 'CD'),
#   (')', ')'),
#   ('Research', 'NN'),
#   ('Fields', 'NNS'),
#   (':', ':'),
#   ('Machine', 'NNP'),
#   ('Learning', 'NNP'),
#   (',', ','),
#   ('Deep', 'NNP'),
#   ('Learning', 'NNP'),
#   (',', ','),
#   ('Big', 'NNP'),
#   ('Data', 'NNP'),
#   ('Analytics', 'NNP'),
#   (',', ','),
#   ('Natural', 'NNP'),
#   ('Language', 'NNP'),
#   ('Processing', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('High', 'NNP'),
#   ('Performance', 'NNP'),
#   ('Computing', 'NNP'),
#   ('Thesis', 'NNP'),
#   ('Title', 'NNP'),
#   (':', ':'),
#   ('Framework', 'NN'),
#   ('for', 'IN'),
#   ('Social', 'NNP'),
#   ('Network', 'NNP'),
#   ('Sentiment', 'NNP'),
#   ('Analysis', 'NNP'),
#   ('Using', 'NNP'),
#   ('Big', 'NNP'),
#   ('Data', 'NNP'),
#   ('Analytics', 'NNP'),
#   ('-', ':'),
#   ('Developed', 'VBD'),
#   ('a', 'DT'),
#   ('generalized', 'JJ'),
#   ('framework', 'NN'),
#   ('for', 'IN'),
#   ('performing', 'VBG'),
#   ('social', 'JJ'),
#   ('network', 'NN'),
#   ('sentiment', 'NN'),
#   ('analysis', 'NN'),
#   ('on', 'IN'),
#   ('any', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('domain', 'NN'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('automobile', 'NN'),
#   (',', ','),
#   ('banking', 'NN'),
#   ('and', 'CC'),
#   ('telecom', 'NN'),
#   ('-', ':'),
#   ('Studied', 'NNP'),
#   ('numerous', 'JJ'),
#   ('research', 'NN'),
#   ('papers', 'NNS'),
#   ('on', 'IN'),
#   ('natural', 'JJ'),
#   ('language', 'NN'),
#   ('processing', 'NN'),
#   (',', ','),
#   ('big', 'JJ'),
#   ('data', 'NNS'),
#   ('analytics', 'NNS'),
#   ('and', 'CC'),
#   ('machine', 'NN'),
#   ('learning', 'VBG'),
#   ('Publication', 'NN'),
#   (':', ':'),
#   ('Big', 'NNP'),
#   ('Data', 'NNP'),
#   ('and', 'CC'),
#   ('Visual', 'NNP'),
#   ('Analytics', 'NNP'),
#   (',', ','),
#   ('Springer', 'NNP'),
#   ('2017', 'CD'),
#   (',', ','),
#   ('Chapter', 'NNP'),
#   ('12', 'CD'),
#   (',', ','),
#   ('Page', 'NN'),
#   (':', ':'),
#   ('203-218', 'JJ'),
#   ('*', 'NN'),
#   ('Case', 'NNP'),
#   ('Study', 'NNP'),
#   (':', ':'),
#   ('Automobile', 'NNP'),
#   ('*', 'VBZ'),
#   ('Popular', 'JJ'),
#   (':', ':'),
#   ('BMW', 'NNP'),
#   ('*', 'NNP'),
#   ('Highest', 'NNP'),
#   ('Sentiment', 'NN'),
#   (':', ':'),
#   ('Mercedes', 'NNP'),
#   ('(', '('),
#   ('0.87', 'CD'),
#   (')', ')'),
#   ('*', 'NN'),
#   ('Lowest', 'NNP'),
#   ('Sentiment', 'NN'),
#   (':', ':'),
#   ('Buick', 'NNP'),
#   ('(', '('),
#   ('0.49', 'CD'),
#   (')', ')'),
#   ('(', '('),
#   ('Jan', 'NNP'),
#   ('2016', 'CD'),
#   ('–May', 'NNP'),
#   ('2018', 'CD'),
#   (')', ')'),
#   ('(', '('),
#   ('Aug', 'JJ'),
#   ('2015', 'CD'),
#   ('–', 'IN'),
#   ('April', 'NNP'),
#   ('2017', 'CD'),
#   (')', ')')]]

# %%
def getName(self, inputString, infoDict, debug=False):
        '''
        Given an input string, returns possible matches for names. Uses regular expression based matching.
        Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
        Modules required: clock from time, code.
        '''

        # Reads Indian Names from the file, reduce all to lower case for easy comparision [Name lists]
        indianNames = open("allNames.txt", "r").read().lower()
        # Lookup in a set is much faster
        indianNames = set(indianNames.split())
        

        otherNameHits = []
        nameHits = []
        name = None
        try:
            # tokens, lines, sentences = self.preprocess(inputString)
            tokens, lines, sentences = self.tokens, self.lines, self.sentences
            # Try a regex chunk parser
            # grammar = r'NAME: {<NN.*><NN.*>|<NN.*><NN.*><NN.*>}'
            grammar = r'NAME: {<NN.*><NN.*><NN.*>*}'
            # Noun phrase chunk is made out of two or three tags of type NN. (ie NN, NNP etc.) - typical of a name. {2,3} won't work, hence the syntax
            # Note the correction to the rule. Change has been made later.
            chunkParser = nltk.RegexpParser(grammar)
            all_chunked_tokens = []
            for tagged_tokens in lines:
                # Creates a parse tree
                if len(tagged_tokens) == 0: continue # Prevent it from printing warnings
                chunked_tokens = chunkParser.parse(tagged_tokens)
                all_chunked_tokens.append(chunked_tokens)
                for subtree in chunked_tokens.subtrees():
                    #  or subtree.label() == 'S' include in if condition if required
                    if subtree.label() == 'NAME':
                        for ind, leaf in enumerate(subtree.leaves()):
                            if leaf[0].lower() in indianNames and 'NN' in leaf[1]:
                                # Case insensitive matching, as indianNames have names in lowercase
                                # Take only noun-tagged tokens
                                # Surname is not in the name list, hence if match is achieved add all noun-type tokens
                                # Pick upto 3 noun entities
                                hit = " ".join([el[0] for el in subtree.leaves()[ind:ind+3]])
                                # Check for the presence of commas, colons, digits - usually markers of non-named entities 
                                if re.compile(r'[\d,:]').search(hit): continue
                                nameHits.append(hit)
                                # Need to iterate through rest of the leaves because of possible mis-matches
            # Going for the first name hit
            if len(nameHits) > 0:
                nameHits = [re.sub(r'[^a-zA-Z \-]', '', el).strip() for el in nameHits] 
                name = " ".join([el[0].upper()+el[1:].lower() for el in nameHits[0].split() if len(el)>0])
                otherNameHits = nameHits[1:]

        except Exception as e:
            print(traceback.format_exc())
            print(e)      

        infoDict['name'] = name
        infoDict['otherNameHits'] = otherNameHits

        if debug:
            print("\n", pprint(infoDict), "\n")
            code.interact(local=locals())
        return name, otherNameHits
